# %% [markdown]
# <a href="https://colab.research.google.com/github/nancymatijas/OSiRV-Projekt/blob/main/task_solve.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
import time
import cv2
import numpy as np
from tqdm import tqdm
from glob import glob
import matplotlib.pyplot as plt
from skimage.transform import resize
import shutil
import nibabel as nib
from IPython.display import clear_output
from PIL import Image
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision
import torchvision.transforms.functional as TF
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !apt-get install tree
# !tree '/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData_jpg/'
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 33 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 0s (160 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 121749 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# /content/drive/MyDrive/MICCAI_BraTS2020_TrainingData_jpg/
# ├── BraTS20_Training_001
# │   ├── BraTS20_Training_001_flair-slice077.jpg
# │   ├── BraTS20_Training_001_seg-slice077.jpg
# │   ├── BraTS20_Training_001_t1ce-slice077.jpg
# │   ├── BraTS20_Training_001_t1-slice077.jpg
# │   └── BraTS20_Training_001_t2-slice077.jpg
# ├── BraTS20_Training_002
# │   ├── BraTS20_Training_002_flair-slice077.jpg
# │   ├── BraTS20_Training_002_seg-slice077.jpg
# │   ├── BraTS20_Training_002_t1ce-slice077.jpg
# │   ├── BraTS20_Training_002_t1-slice077.jpg
# │   └── BraTS20_Training_002_t2-slice077.jpg
# ├── BraTS20_Training_003
# │   ├── BraTS20_Training_003_flair-slice077.jpg
# │   ├── BraTS20_Training_003_seg-slice077.jpg
# │   ├── BraTS20_Training_003_t1ce-slice077.jpg
# │   ├── BraTS20_Training_003_t1-slice077.jpg
# │   └── BraTS20_Training_003_t2-slice077.jpg
# ├── BraTS20_Training_004
# │   ├── BraTS20_Training_004_flair-slice077.jpg
# │   ├── BraTS20_Training_004_seg-slice077.jpg
# │   ├── BraTS20_Training_004_t1ce-slice077.jpg
# │   ├── BraTS20_Training_004_t1-slice077.jpg
# │   └── BraTS20_Training_004_t2-slice077.jpg
# ├── BraTS20_Training_005
# │   ├── BraTS20_Training_005_flair-slice077.jpg
# │   ├── BraTS20_Training_005_seg-slice077.jpg
# │   ├── BraTS20_Training_005_t1ce-slice077.jpg
# │   ├── BraTS20_Training_005_t1-slice077.jpg
# │   └── BraTS20_Training_005_t2-slice077.jpg
# ├── BraTS20_Training_006
# │   ├── BraTS20_Training_006_flair-slice077.jpg
# │   ├── BraTS20_Training_006_seg-slice077.jpg
# │   ├── BraTS20_Training_006_t1ce-slice077.jpg
# │   ├── BraTS20_Training_006_t1-slice077.jpg
# │   └── BraTS20_Training_006_t2-slice077.jpg
# ├── BraTS20_Training_007
# │   ├── BraTS20_Training_007_flair-slice077.jpg
# │   ├── BraTS20_Training_007_seg-slice077.jpg
# │   ├── BraTS20_Training_007_t1ce-slice077.jpg
# │   ├── BraTS20_Training_007_t1-slice077.jpg
# │   └── BraTS20_Training_007_t2-slice077.jpg
# ├── BraTS20_Training_008
# │   ├── BraTS20_Training_008_flair-slice077.jpg
# │   ├── BraTS20_Training_008_seg-slice077.jpg
# │   ├── BraTS20_Training_008_t1ce-slice077.jpg
# │   ├── BraTS20_Training_008_t1-slice077.jpg
# │   └── BraTS20_Training_008_t2-slice077.jpg
# ├── BraTS20_Training_009
# │   ├── BraTS20_Training_009_flair-slice077.jpg
# │   ├── BraTS20_Training_009_seg-slice077.jpg
# │   ├── BraTS20_Training_009_t1ce-slice077.jpg
# │   ├── BraTS20_Training_009_t1-slice077.jpg
# │   └── BraTS20_Training_009_t2-slice077.jpg
# ├── BraTS20_Training_010
# │   ├── BraTS20_Training_010_flair-slice077.jpg
# │   ├── BraTS20_Training_010_seg-slice077.jpg
# │   ├── BraTS20_Training_010_t1ce-slice077.jpg
# │   ├── BraTS20_Training_010_t1-slice077.jpg
# │   └── BraTS20_Training_010_t2-slice077.jpg
# ├── BraTS20_Training_011
# │   ├── BraTS20_Training_011_flair-slice077.jpg
# │   ├── BraTS20_Training_011_seg-slice077.jpg
# │   ├── BraTS20_Training_011_t1ce-slice077.jpg
# │   ├── BraTS20_Training_011_t1-slice077.jpg
# │   └── BraTS20_Training_011_t2-slice077.jpg
# ├── BraTS20_Training_012
# │   ├── BraTS20_Training_012_flair-slice077.jpg
# │   ├── BraTS20_Training_012_seg-slice077.jpg
# │   ├── BraTS20_Training_012_t1ce-slice077.jpg
# │   ├── BraTS20_Training_012_t1-slice077.jpg
# │   └── BraTS20_Training_012_t2-slice077.jpg
# ├── BraTS20_Training_013
# │   ├── BraTS20_Training_013_flair-slice077.jpg
# │   ├── BraTS20_Training_013_seg-slice077.jpg
# │   ├── BraTS20_Training_013_t1ce-slice077.jpg
# │   ├── BraTS20_Training_013_t1-slice077.jpg
# │   └── BraTS20_Training_013_t2-slice077.jpg
# ├── BraTS20_Training_014
# │   ├── BraTS20_Training_014_flair-slice077.jpg
# │   ├── BraTS20_Training_014_seg-slice077.jpg
# │   ├── BraTS20_Training_014_t1ce-slice077.jpg
# │   ├── BraTS20_Training_014_t1-slice077.jpg
# │   └── BraTS20_Training_014_t2-slice077.jpg
# ├── BraTS20_Training_015
# │   ├── BraTS20_Training_015_flair-slice077.jpg
# │   ├── BraTS20_Training_015_seg-slice077.jpg
# │   ├── BraTS20_Training_015_t1ce-slice077.jpg
# │   ├── BraTS20_Training_015_t1-slice077.jpg
# │   └── BraTS20_Training_015_t2-slice077.jpg
# ├── BraTS20_Training_016
# │   ├── BraTS20_Training_016_flair-slice077.jpg
# │   ├── BraTS20_Training_016_seg-slice077.jpg
# │   ├── BraTS20_Training_016_t1ce-slice077.jpg
# │   ├── BraTS20_Training_016_t1-slice077.jpg
# │   └── BraTS20_Training_016_t2-slice077.jpg
# ├── BraTS20_Training_017
# │   ├── BraTS20_Training_017_flair-slice077.jpg
# │   ├── BraTS20_Training_017_seg-slice077.jpg
# │   ├── BraTS20_Training_017_t1ce-slice077.jpg
# │   ├── BraTS20_Training_017_t1-slice077.jpg
# │   └── BraTS20_Training_017_t2-slice077.jpg
# ├── BraTS20_Training_018
# │   ├── BraTS20_Training_018_flair-slice077.jpg
# │   ├── BraTS20_Training_018_seg-slice077.jpg
# │   ├── BraTS20_Training_018_t1ce-slice077.jpg
# │   ├── BraTS20_Training_018_t1-slice077.jpg
# │   └── BraTS20_Training_018_t2-slice077.jpg
# ├── BraTS20_Training_019
# │   ├── BraTS20_Training_019_flair-slice077.jpg
# │   ├── BraTS20_Training_019_seg-slice077.jpg
# │   ├── BraTS20_Training_019_t1ce-slice077.jpg
# │   ├── BraTS20_Training_019_t1-slice077.jpg
# │   └── BraTS20_Training_019_t2-slice077.jpg
# ├── BraTS20_Training_020
# │   ├── BraTS20_Training_020_flair-slice077.jpg
# │   ├── BraTS20_Training_020_seg-slice077.jpg
# │   ├── BraTS20_Training_020_t1ce-slice077.jpg
# │   ├── BraTS20_Training_020_t1-slice077.jpg
# │   └── BraTS20_Training_020_t2-slice077.jpg
# ├── BraTS20_Training_021
# │   ├── BraTS20_Training_021_flair-slice077.jpg
# │   ├── BraTS20_Training_021_seg-slice077.jpg
# │   ├── BraTS20_Training_021_t1ce-slice077.jpg
# │   ├── BraTS20_Training_021_t1-slice077.jpg
# │   └── BraTS20_Training_021_t2-slice077.jpg
# ├── BraTS20_Training_022
# │   ├── BraTS20_Training_022_flair-slice077.jpg
# │   ├── BraTS20_Training_022_seg-slice077.jpg
# │   ├── BraTS20_Training_022_t1ce-slice077.jpg
# │   ├── BraTS20_Training_022_t1-slice077.jpg
# │   └── BraTS20_Training_022_t2-slice077.jpg
# ├── BraTS20_Training_023
# │   ├── BraTS20_Training_023_flair-slice077.jpg
# │   ├── BraTS20_Training_023_seg-slice077.jpg
# │   ├── BraTS20_Training_023_t1ce-slice077.jpg
# │   ├── BraTS20_Training_023_t1-slice077.jpg
# │   └── BraTS20_Training_023_t2-slice077.jpg
# ├── BraTS20_Training_024
# │   ├── BraTS20_Training_024_flair-slice077.jpg
# │   ├── BraTS20_Training_024_seg-slice077.jpg
# │   ├── BraTS20_Training_024_t1ce-slice077.jpg
# │   ├── BraTS20_Training_024_t1-slice077.jpg
# │   └── BraTS20_Training_024_t2-slice077.jpg
# ├── BraTS20_Training_025
# │   ├── BraTS20_Training_025_flair-slice077.jpg
# │   ├── BraTS20_Training_025_seg-slice077.jpg
# │   ├── BraTS20_Training_025_t1ce-slice077.jpg
# │   ├── BraTS20_Training_025_t1-slice077.jpg
# │   └── BraTS20_Training_025_t2-slice077.jpg
# ├── BraTS20_Training_026
# │   ├── BraTS20_Training_026_flair-slice077.jpg
# │   ├── BraTS20_Training_026_seg-slice077.jpg
# │   ├── BraTS20_Training_026_t1ce-slice077.jpg
# │   ├── BraTS20_Training_026_t1-slice077.jpg
# │   └── BraTS20_Training_026_t2-slice077.jpg
# ├── BraTS20_Training_027
# │   ├── BraTS20_Training_027_flair-slice077.jpg
# │   ├── BraTS20_Training_027_seg-slice077.jpg
# │   ├── BraTS20_Training_027_t1ce-slice077.jpg
# │   ├── BraTS20_Training_027_t1-slice077.jpg
# │   └── BraTS20_Training_027_t2-slice077.jpg
# ├── BraTS20_Training_028
# │   ├── BraTS20_Training_028_flair-slice077.jpg
# │   ├── BraTS20_Training_028_seg-slice077.jpg
# │   ├── BraTS20_Training_028_t1ce-slice077.jpg
# │   ├── BraTS20_Training_028_t1-slice077.jpg
# │   └── BraTS20_Training_028_t2-slice077.jpg
# ├── BraTS20_Training_029
# │   ├── BraTS20_Training_029_flair-slice077.jpg
# │   ├── BraTS20_Training_029_seg-slice077.jpg
# │   ├── BraTS20_Training_029_t1ce-slice077.jpg
# │   ├── BraTS20_Training_029_t1-slice077.jpg
# │   └── BraTS20_Training_029_t2-slice077.jpg
# ├── BraTS20_Training_030
# │   ├── BraTS20_Training_030_flair-slice077.jpg
# │   ├── BraTS20_Training_030_seg-slice077.jpg
# │   ├── BraTS20_Training_030_t1ce-slice077.jpg
# │   ├── BraTS20_Training_030_t1-slice077.jpg
# │   └── BraTS20_Training_030_t2-slice077.jpg
# ├── BraTS20_Training_031
# │   ├── BraTS20_Training_031_flair-slice077.jpg
# │   ├── BraTS20_Training_031_seg-slice077.jpg
# │   ├── BraTS20_Training_031_t1ce-slice077.jpg
# │   ├── BraTS20_Training_031_t1-slice077.jpg
# │   └── BraTS20_Training_031_t2-slice077.jpg
# ├── BraTS20_Training_032
# │   ├── BraTS20_Training_032_flair-slice077.jpg
# │   ├── BraTS20_Training_032_seg-slice077.jpg
# │   ├── BraTS20_Training_032_t1ce-slice077.jpg
# │   ├── BraTS20_Training_032_t1-slice077.jpg
# │   └── BraTS20_Training_032_t2-slice077.jpg
# ├── BraTS20_Training_033
# │   ├── BraTS20_Training_033_flair-slice077.jpg
# │   ├── BraTS20_Training_033_seg-slice077.jpg
# │   ├── BraTS20_Training_033_t1ce-slice077.jpg
# │   ├── BraTS20_Training_033_t1-slice077.jpg
# │   └── BraTS20_Training_033_t2-slice077.jpg
# ├── BraTS20_Training_034
# │   ├── BraTS20_Training_034_flair-slice077.jpg
# │   ├── BraTS20_Training_034_seg-slice077.jpg
# │   ├── BraTS20_Training_034_t1ce-slice077.jpg
# │   ├── BraTS20_Training_034_t1-slice077.jpg
# │   └── BraTS20_Training_034_t2-slice077.jpg
# ├── BraTS20_Training_035
# │   ├── BraTS20_Training_035_flair-slice077.jpg
# │   ├── BraTS20_Training_035_seg-slice077.jpg
# │   ├── BraTS20_Training_035_t1ce-slice077.jpg
# │   ├── BraTS20_Training_035_t1-slice077.jpg
# │   └── BraTS20_Training_035_t2-slice077.jpg
# ├── BraTS20_Training_036
# │   ├── BraTS20_Training_036_flair-slice077.jpg
# │   ├── BraTS20_Training_036_seg-slice077.jpg
# │   ├── BraTS20_Training_036_t1ce-slice077.jpg
# │   ├── BraTS20_Training_036_t1-slice077.jpg
# │   └── BraTS20_Training_036_t2-slice077.jpg
# ├── BraTS20_Training_037
# │   ├── BraTS20_Training_037_flair-slice077.jpg
# │   ├── BraTS20_Training_037_seg-slice077.jpg
# │   ├── BraTS20_Training_037_t1ce-slice077.jpg
# │   ├── BraTS20_Training_037_t1-slice077.jpg
# │   └── BraTS20_Training_037_t2-slice077.jpg
# ├── BraTS20_Training_038
# │   ├── BraTS20_Training_038_flair-slice077.jpg
# │   ├── BraTS20_Training_038_seg-slice077.jpg
# │   ├── BraTS20_Training_038_t1ce-slice077.jpg
# │   ├── BraTS20_Training_038_t1-slice077.jpg
# │   └── BraTS20_Training_038_t2-slice077.jpg
# ├── BraTS20_Training_039
# │   ├── BraTS20_Training_039_flair-slice077.jpg
# │   ├── BraTS20_Training_039_seg-slice077.jpg
# │   ├── BraTS20_Training_039_t1ce-slice077.jpg
# │   ├── BraTS20_Training_039_t1-slice077.jpg
# │   └── BraTS20_Training_039_t2-slice077.jpg
# ├── BraTS20_Training_040
# │   ├── BraTS20_Training_040_flair-slice077.jpg
# │   ├── BraTS20_Training_040_seg-slice077.jpg
# │   ├── BraTS20_Training_040_t1ce-slice077.jpg
# │   ├── BraTS20_Training_040_t1-slice077.jpg
# │   └── BraTS20_Training_040_t2-slice077.jpg
# ├── BraTS20_Training_041
# │   ├── BraTS20_Training_041_flair-slice077.jpg
# │   ├── BraTS20_Training_041_seg-slice077.jpg
# │   ├── BraTS20_Training_041_t1ce-slice077.jpg
# │   ├── BraTS20_Training_041_t1-slice077.jpg
# │   └── BraTS20_Training_041_t2-slice077.jpg
# ├── BraTS20_Training_042
# │   ├── BraTS20_Training_042_flair-slice077.jpg
# │   ├── BraTS20_Training_042_seg-slice077.jpg
# │   ├── BraTS20_Training_042_t1ce-slice077.jpg
# │   ├── BraTS20_Training_042_t1-slice077.jpg
# │   └── BraTS20_Training_042_t2-slice077.jpg
# ├── BraTS20_Training_043
# │   ├── BraTS20_Training_043_flair-slice077.jpg
# │   ├── BraTS20_Training_043_seg-slice077.jpg
# │   ├── BraTS20_Training_043_t1ce-slice077.jpg
# │   ├── BraTS20_Training_043_t1-slice077.jpg
# │   └── BraTS20_Training_043_t2-slice077.jpg
# ├── BraTS20_Training_044
# │   ├── BraTS20_Training_044_flair-slice077.jpg
# │   ├── BraTS20_Training_044_seg-slice077.jpg
# │   ├── BraTS20_Training_044_t1ce-slice077.jpg
# │   ├── BraTS20_Training_044_t1-slice077.jpg
# │   └── BraTS20_Training_044_t2-slice077.jpg
# ├── BraTS20_Training_045
# │   ├── BraTS20_Training_045_flair-slice077.jpg
# │   ├── BraTS20_Training_045_seg-slice077.jpg
# │   ├── BraTS20_Training_045_t1ce-slice077.jpg
# │   ├── BraTS20_Training_045_t1-slice077.jpg
# │   └── BraTS20_Training_045_t2-slice077.jpg
# ├── BraTS20_Training_046
# │   ├── BraTS20_Training_046_flair-slice077.jpg
# │   ├── BraTS20_Training_046_seg-slice077.jpg
# │   ├── BraTS20_Training_046_t1ce-slice077.jpg
# │   ├── BraTS20_Training_046_t1-slice077.jpg
# │   └── BraTS20_Training_046_t2-slice077.jpg
# ├── BraTS20_Training_047
# │   ├── BraTS20_Training_047_flair-slice077.jpg
# │   ├── BraTS20_Training_047_seg-slice077.jpg
# │   ├── BraTS20_Training_047_t1ce-slice077.jpg
# │   ├── BraTS20_Training_047_t1-slice077.jpg
# │   └── BraTS20_Training_047_t2-slice077.jpg
# ├── BraTS20_Training_048
# │   ├── BraTS20_Training_048_flair-slice077.jpg
# │   ├── BraTS20_Training_048_seg-slice077.jpg
# │   ├── BraTS20_Training_048_t1ce-slice077.jpg
# │   ├── BraTS20_Training_048_t1-slice077.jpg
# │   └── BraTS20_Training_048_t2-slice077.jpg
# ├── BraTS20_Training_049
# │   ├── BraTS20_Training_049_flair-slice077.jpg
# │   ├── BraTS20_Training_049_seg-slice077.jpg
# │   ├── BraTS20_Training_049_t1ce-slice077.jpg
# │   ├── BraTS20_Training_049_t1-slice077.jpg
# │   └── BraTS20_Training_049_t2-slice077.jpg
# ├── BraTS20_Training_050
# │   ├── BraTS20_Training_050_flair-slice077.jpg
# │   ├── BraTS20_Training_050_seg-slice077.jpg
# │   ├── BraTS20_Training_050_t1ce-slice077.jpg
# │   ├── BraTS20_Training_050_t1-slice077.jpg
# │   └── BraTS20_Training_050_t2-slice077.jpg
# ├── BraTS20_Training_051
# │   ├── BraTS20_Training_051_flair-slice077.jpg
# │   ├── BraTS20_Training_051_seg-slice077.jpg
# │   ├── BraTS20_Training_051_t1ce-slice077.jpg
# │   ├── BraTS20_Training_051_t1-slice077.jpg
# │   └── BraTS20_Training_051_t2-slice077.jpg
# ├── BraTS20_Training_052
# │   ├── BraTS20_Training_052_flair-slice077.jpg
# │   ├── BraTS20_Training_052_seg-slice077.jpg
# │   ├── BraTS20_Training_052_t1ce-slice077.jpg
# │   ├── BraTS20_Training_052_t1-slice077.jpg
# │   └── BraTS20_Training_052_t2-slice077.jpg
# ├── BraTS20_Training_053
# │   ├── BraTS20_Training_053_flair-slice077.jpg
# │   ├── BraTS20_Training_053_seg-slice077.jpg
# │   ├── BraTS20_Training_053_t1ce-slice077.jpg
# │   ├── BraTS20_Training_053_t1-slice077.jpg
# │   └── BraTS20_Training_053_t2-slice077.jpg
# ├── BraTS20_Training_054
# │   ├── BraTS20_Training_054_flair-slice077.jpg
# │   ├── BraTS20_Training_054_seg-slice077.jpg
# │   ├── BraTS20_Training_054_t1ce-slice077.jpg
# │   ├── BraTS20_Training_054_t1-slice077.jpg
# │   └── BraTS20_Training_054_t2-slice077.jpg
# ├── BraTS20_Training_055
# │   ├── BraTS20_Training_055_flair-slice077.jpg
# │   ├── BraTS20_Training_055_seg-slice077.jpg
# │   ├── BraTS20_Training_055_t1ce-slice077.jpg
# │   ├── BraTS20_Training_055_t1-slice077.jpg
# │   └── BraTS20_Training_055_t2-slice077.jpg
# ├── BraTS20_Training_056
# │   ├── BraTS20_Training_056_flair-slice077.jpg
# │   ├── BraTS20_Training_056_seg-slice077.jpg
# │   ├── BraTS20_Training_056_t1ce-slice077.jpg
# │   ├── BraTS20_Training_056_t1-slice077.jpg
# │   └── BraTS20_Training_056_t2-slice077.jpg
# ├── BraTS20_Training_057
# │   ├── BraTS20_Training_057_flair-slice077.jpg
# │   ├── BraTS20_Training_057_seg-slice077.jpg
# │   ├── BraTS20_Training_057_t1ce-slice077.jpg
# │   ├── BraTS20_Training_057_t1-slice077.jpg
# │   └── BraTS20_Training_057_t2-slice077.jpg
# ├── BraTS20_Training_058
# │   ├── BraTS20_Training_058_flair-slice077.jpg
# │   ├── BraTS20_Training_058_seg-slice077.jpg
# │   ├── BraTS20_Training_058_t1ce-slice077.jpg
# │   ├── BraTS20_Training_058_t1-slice077.jpg
# │   └── BraTS20_Training_058_t2-slice077.jpg
# ├── BraTS20_Training_059
# │   ├── BraTS20_Training_059_flair-slice077.jpg
# │   ├── BraTS20_Training_059_seg-slice077.jpg
# │   ├── BraTS20_Training_059_t1ce-slice077.jpg
# │   ├── BraTS20_Training_059_t1-slice077.jpg
# │   └── BraTS20_Training_059_t2-slice077.jpg
# ├── BraTS20_Training_060
# │   ├── BraTS20_Training_060_flair-slice077.jpg
# │   ├── BraTS20_Training_060_seg-slice077.jpg
# │   ├── BraTS20_Training_060_t1ce-slice077.jpg
# │   ├── BraTS20_Training_060_t1-slice077.jpg
# │   └── BraTS20_Training_060_t2-slice077.jpg
# ├── BraTS20_Training_061
# │   ├── BraTS20_Training_061_flair-slice077.jpg
# │   ├── BraTS20_Training_061_seg-slice077.jpg
# │   ├── BraTS20_Training_061_t1ce-slice077.jpg
# │   ├── BraTS20_Training_061_t1-slice077.jpg
# │   └── BraTS20_Training_061_t2-slice077.jpg
# ├── BraTS20_Training_062
# │   ├── BraTS20_Training_062_flair-slice077.jpg
# │   ├── BraTS20_Training_062_seg-slice077.jpg
# │   ├── BraTS20_Training_062_t1ce-slice077.jpg
# │   ├── BraTS20_Training_062_t1-slice077.jpg
# │   └── BraTS20_Training_062_t2-slice077.jpg
# ├── BraTS20_Training_063
# │   ├── BraTS20_Training_063_flair-slice077.jpg
# │   ├── BraTS20_Training_063_seg-slice077.jpg
# │   ├── BraTS20_Training_063_t1ce-slice077.jpg
# │   ├── BraTS20_Training_063_t1-slice077.jpg
# │   └── BraTS20_Training_063_t2-slice077.jpg
# ├── BraTS20_Training_064
# │   ├── BraTS20_Training_064_flair-slice077.jpg
# │   ├── BraTS20_Training_064_seg-slice077.jpg
# │   ├── BraTS20_Training_064_t1ce-slice077.jpg
# │   ├── BraTS20_Training_064_t1-slice077.jpg
# │   └── BraTS20_Training_064_t2-slice077.jpg
# ├── BraTS20_Training_065
# │   ├── BraTS20_Training_065_flair-slice077.jpg
# │   ├── BraTS20_Training_065_seg-slice077.jpg
# │   ├── BraTS20_Training_065_t1ce-slice077.jpg
# │   ├── BraTS20_Training_065_t1-slice077.jpg
# │   └── BraTS20_Training_065_t2-slice077.jpg
# ├── BraTS20_Training_066
# │   ├── BraTS20_Training_066_flair-slice077.jpg
# │   ├── BraTS20_Training_066_seg-slice077.jpg
# │   ├── BraTS20_Training_066_t1ce-slice077.jpg
# │   ├── BraTS20_Training_066_t1-slice077.jpg
# │   └── BraTS20_Training_066_t2-slice077.jpg
# ├── BraTS20_Training_067
# │   ├── BraTS20_Training_067_flair-slice077.jpg
# │   ├── BraTS20_Training_067_seg-slice077.jpg
# │   ├── BraTS20_Training_067_t1ce-slice077.jpg
# │   ├── BraTS20_Training_067_t1-slice077.jpg
# │   └── BraTS20_Training_067_t2-slice077.jpg
# ├── BraTS20_Training_068
# │   ├── BraTS20_Training_068_flair-slice077.jpg
# │   ├── BraTS20_Training_068_seg-slice077.jpg
# │   ├── BraTS20_Training_068_t1ce-slice077.jpg
# │   ├── BraTS20_Training_068_t1-slice077.jpg
# │   └── BraTS20_Training_068_t2-slice077.jpg
# ├── BraTS20_Training_069
# │   ├── BraTS20_Training_069_flair-slice077.jpg
# │   ├── BraTS20_Training_069_seg-slice077.jpg
# │   ├── BraTS20_Training_069_t1ce-slice077.jpg
# │   ├── BraTS20_Training_069_t1-slice077.jpg
# │   └── BraTS20_Training_069_t2-slice077.jpg
# ├── BraTS20_Training_070
# │   ├── BraTS20_Training_070_flair-slice077.jpg
# │   ├── BraTS20_Training_070_seg-slice077.jpg
# │   ├── BraTS20_Training_070_t1ce-slice077.jpg
# │   ├── BraTS20_Training_070_t1-slice077.jpg
# │   └── BraTS20_Training_070_t2-slice077.jpg
# ├── BraTS20_Training_071
# │   ├── BraTS20_Training_071_flair-slice077.jpg
# │   ├── BraTS20_Training_071_seg-slice077.jpg
# │   ├── BraTS20_Training_071_t1ce-slice077.jpg
# │   ├── BraTS20_Training_071_t1-slice077.jpg
# │   └── BraTS20_Training_071_t2-slice077.jpg
# ├── BraTS20_Training_072
# │   ├── BraTS20_Training_072_flair-slice077.jpg
# │   ├── BraTS20_Training_072_seg-slice077.jpg
# │   ├── BraTS20_Training_072_t1ce-slice077.jpg
# │   ├── BraTS20_Training_072_t1-slice077.jpg
# │   └── BraTS20_Training_072_t2-slice077.jpg
# ├── BraTS20_Training_073
# │   ├── BraTS20_Training_073_flair-slice077.jpg
# │   ├── BraTS20_Training_073_seg-slice077.jpg
# │   ├── BraTS20_Training_073_t1ce-slice077.jpg
# │   ├── BraTS20_Training_073_t1-slice077.jpg
# │   └── BraTS20_Training_073_t2-slice077.jpg
# ├── BraTS20_Training_074
# │   ├── BraTS20_Training_074_flair-slice077.jpg
# │   ├── BraTS20_Training_074_seg-slice077.jpg
# │   ├── BraTS20_Training_074_t1ce-slice077.jpg
# │   ├── BraTS20_Training_074_t1-slice077.jpg
# │   └── BraTS20_Training_074_t2-slice077.jpg
# ├── BraTS20_Training_075
# │   ├── BraTS20_Training_075_flair-slice077.jpg
# │   ├── BraTS20_Training_075_seg-slice077.jpg
# │   ├── BraTS20_Training_075_t1ce-slice077.jpg
# │   ├── BraTS20_Training_075_t1-slice077.jpg
# │   └── BraTS20_Training_075_t2-slice077.jpg
# ├── BraTS20_Training_076
# │   ├── BraTS20_Training_076_flair-slice077.jpg
# │   ├── BraTS20_Training_076_seg-slice077.jpg
# │   ├── BraTS20_Training_076_t1ce-slice077.jpg
# │   ├── BraTS20_Training_076_t1-slice077.jpg
# │   └── BraTS20_Training_076_t2-slice077.jpg
# ├── BraTS20_Training_077
# │   ├── BraTS20_Training_077_flair-slice077.jpg
# │   ├── BraTS20_Training_077_seg-slice077.jpg
# │   ├── BraTS20_Training_077_t1ce-slice077.jpg
# │   ├── BraTS20_Training_077_t1-slice077.jpg
# │   └── BraTS20_Training_077_t2-slice077.jpg
# ├── BraTS20_Training_078
# │   ├── BraTS20_Training_078_flair-slice077.jpg
# │   ├── BraTS20_Training_078_seg-slice077.jpg
# │   ├── BraTS20_Training_078_t1ce-slice077.jpg
# │   ├── BraTS20_Training_078_t1-slice077.jpg
# │   └── BraTS20_Training_078_t2-slice077.jpg
# ├── BraTS20_Training_079
# │   ├── BraTS20_Training_079_flair-slice077.jpg
# │   ├── BraTS20_Training_079_seg-slice077.jpg
# │   ├── BraTS20_Training_079_t1ce-slice077.jpg
# │   ├── BraTS20_Training_079_t1-slice077.jpg
# │   └── BraTS20_Training_079_t2-slice077.jpg
# ├── BraTS20_Training_080
# │   ├── BraTS20_Training_080_flair-slice077.jpg
# │   ├── BraTS20_Training_080_seg-slice077.jpg
# │   ├── BraTS20_Training_080_t1ce-slice077.jpg
# │   ├── BraTS20_Training_080_t1-slice077.jpg
# │   └── BraTS20_Training_080_t2-slice077.jpg
# ├── BraTS20_Training_081
# │   ├── BraTS20_Training_081_flair-slice077.jpg
# │   ├── BraTS20_Training_081_seg-slice077.jpg
# │   ├── BraTS20_Training_081_t1ce-slice077.jpg
# │   ├── BraTS20_Training_081_t1-slice077.jpg
# │   └── BraTS20_Training_081_t2-slice077.jpg
# ├── BraTS20_Training_082
# │   ├── BraTS20_Training_082_flair-slice077.jpg
# │   ├── BraTS20_Training_082_seg-slice077.jpg
# │   ├── BraTS20_Training_082_t1ce-slice077.jpg
# │   ├── BraTS20_Training_082_t1-slice077.jpg
# │   └── BraTS20_Training_082_t2-slice077.jpg
# ├── BraTS20_Training_083
# │   ├── BraTS20_Training_083_flair-slice077.jpg
# │   ├── BraTS20_Training_083_seg-slice077.jpg
# │   ├── BraTS20_Training_083_t1ce-slice077.jpg
# │   ├── BraTS20_Training_083_t1-slice077.jpg
# │   └── BraTS20_Training_083_t2-slice077.jpg
# ├── BraTS20_Training_084
# │   ├── BraTS20_Training_084_flair-slice077.jpg
# │   ├── BraTS20_Training_084_seg-slice077.jpg
# │   ├── BraTS20_Training_084_t1ce-slice077.jpg
# │   ├── BraTS20_Training_084_t1-slice077.jpg
# │   └── BraTS20_Training_084_t2-slice077.jpg
# ├── BraTS20_Training_085
# │   ├── BraTS20_Training_085_flair-slice077.jpg
# │   ├── BraTS20_Training_085_seg-slice077.jpg
# │   ├── BraTS20_Training_085_t1ce-slice077.jpg
# │   ├── BraTS20_Training_085_t1-slice077.jpg
# │   └── BraTS20_Training_085_t2-slice077.jpg
# ├── BraTS20_Training_086
# │   ├── BraTS20_Training_086_flair-slice077.jpg
# │   ├── BraTS20_Training_086_seg-slice077.jpg
# │   ├── BraTS20_Training_086_t1ce-slice077.jpg
# │   ├── BraTS20_Training_086_t1-slice077.jpg
# │   └── BraTS20_Training_086_t2-slice077.jpg
# ├── BraTS20_Training_087
# │   ├── BraTS20_Training_087_flair-slice077.jpg
# │   ├── BraTS20_Training_087_seg-slice077.jpg
# │   ├── BraTS20_Training_087_t1ce-slice077.jpg
# │   ├── BraTS20_Training_087_t1-slice077.jpg
# │   └── BraTS20_Training_087_t2-slice077.jpg
# ├── BraTS20_Training_088
# │   ├── BraTS20_Training_088_flair-slice077.jpg
# │   ├── BraTS20_Training_088_seg-slice077.jpg
# │   ├── BraTS20_Training_088_t1ce-slice077.jpg
# │   ├── BraTS20_Training_088_t1-slice077.jpg
# │   └── BraTS20_Training_088_t2-slice077.jpg
# ├── BraTS20_Training_089
# │   ├── BraTS20_Training_089_flair-slice077.jpg
# │   ├── BraTS20_Training_089_seg-slice077.jpg
# │   ├── BraTS20_Training_089_t1ce-slice077.jpg
# │   ├── BraTS20_Training_089_t1-slice077.jpg
# │   └── BraTS20_Training_089_t2-slice077.jpg
# ├── BraTS20_Training_090
# │   ├── BraTS20_Training_090_flair-slice077.jpg
# │   ├── BraTS20_Training_090_seg-slice077.jpg
# │   ├── BraTS20_Training_090_t1ce-slice077.jpg
# │   ├── BraTS20_Training_090_t1-slice077.jpg
# │   └── BraTS20_Training_090_t2-slice077.jpg
# ├── BraTS20_Training_091
# │   ├── BraTS20_Training_091_flair-slice077.jpg
# │   ├── BraTS20_Training_091_seg-slice077.jpg
# │   ├── BraTS20_Training_091_t1ce-slice077.jpg
# │   ├── BraTS20_Training_091_t1-slice077.jpg
# │   └── BraTS20_Training_091_t2-slice077.jpg
# ├── BraTS20_Training_092
# │   ├── BraTS20_Training_092_flair-slice077.jpg
# │   ├── BraTS20_Training_092_seg-slice077.jpg
# │   ├── BraTS20_Training_092_t1ce-slice077.jpg
# │   ├── BraTS20_Training_092_t1-slice077.jpg
# │   └── BraTS20_Training_092_t2-slice077.jpg
# ├── BraTS20_Training_093
# │   ├── BraTS20_Training_093_flair-slice077.jpg
# │   ├── BraTS20_Training_093_seg-slice077.jpg
# │   ├── BraTS20_Training_093_t1ce-slice077.jpg
# │   ├── BraTS20_Training_093_t1-slice077.jpg
# │   └── BraTS20_Training_093_t2-slice077.jpg
# ├── BraTS20_Training_094
# │   ├── BraTS20_Training_094_flair-slice077.jpg
# │   ├── BraTS20_Training_094_seg-slice077.jpg
# │   ├── BraTS20_Training_094_t1ce-slice077.jpg
# │   ├── BraTS20_Training_094_t1-slice077.jpg
# │   └── BraTS20_Training_094_t2-slice077.jpg
# ├── BraTS20_Training_095
# │   ├── BraTS20_Training_095_flair-slice077.jpg
# │   ├── BraTS20_Training_095_seg-slice077.jpg
# │   ├── BraTS20_Training_095_t1ce-slice077.jpg
# │   ├── BraTS20_Training_095_t1-slice077.jpg
# │   └── BraTS20_Training_095_t2-slice077.jpg
# ├── BraTS20_Training_096
# │   ├── BraTS20_Training_096_flair-slice077.jpg
# │   ├── BraTS20_Training_096_seg-slice077.jpg
# │   ├── BraTS20_Training_096_t1ce-slice077.jpg
# │   ├── BraTS20_Training_096_t1-slice077.jpg
# │   └── BraTS20_Training_096_t2-slice077.jpg
# ├── BraTS20_Training_097
# │   ├── BraTS20_Training_097_flair-slice077.jpg
# │   ├── BraTS20_Training_097_seg-slice077.jpg
# │   ├── BraTS20_Training_097_t1ce-slice077.jpg
# │   ├── BraTS20_Training_097_t1-slice077.jpg
# │   └── BraTS20_Training_097_t2-slice077.jpg
# ├── BraTS20_Training_098
# │   ├── BraTS20_Training_098_flair-slice077.jpg
# │   ├── BraTS20_Training_098_seg-slice077.jpg
# │   ├── BraTS20_Training_098_t1ce-slice077.jpg
# │   ├── BraTS20_Training_098_t1-slice077.jpg
# │   └── BraTS20_Training_098_t2-slice077.jpg
# ├── BraTS20_Training_099
# │   ├── BraTS20_Training_099_flair-slice077.jpg
# │   ├── BraTS20_Training_099_seg-slice077.jpg
# │   ├── BraTS20_Training_099_t1ce-slice077.jpg
# │   ├── BraTS20_Training_099_t1-slice077.jpg
# │   └── BraTS20_Training_099_t2-slice077.jpg
# ├── BraTS20_Training_100
# │   ├── BraTS20_Training_100_flair-slice077.jpg
# │   ├── BraTS20_Training_100_seg-slice077.jpg
# │   ├── BraTS20_Training_100_t1ce-slice077.jpg
# │   ├── BraTS20_Training_100_t1-slice077.jpg
# │   └── BraTS20_Training_100_t2-slice077.jpg
# ├── BraTS20_Training_101
# │   ├── BraTS20_Training_101_flair-slice077.jpg
# │   ├── BraTS20_Training_101_seg-slice077.jpg
# │   ├── BraTS20_Training_101_t1ce-slice077.jpg
# │   ├── BraTS20_Training_101_t1-slice077.jpg
# │   └── BraTS20_Training_101_t2-slice077.jpg
# ├── BraTS20_Training_102
# │   ├── BraTS20_Training_102_flair-slice077.jpg
# │   ├── BraTS20_Training_102_seg-slice077.jpg
# │   ├── BraTS20_Training_102_t1ce-slice077.jpg
# │   ├── BraTS20_Training_102_t1-slice077.jpg
# │   └── BraTS20_Training_102_t2-slice077.jpg
# ├── BraTS20_Training_103
# │   ├── BraTS20_Training_103_flair-slice077.jpg
# │   ├── BraTS20_Training_103_seg-slice077.jpg
# │   ├── BraTS20_Training_103_t1ce-slice077.jpg
# │   ├── BraTS20_Training_103_t1-slice077.jpg
# │   └── BraTS20_Training_103_t2-slice077.jpg
# ├── BraTS20_Training_104
# │   ├── BraTS20_Training_104_flair-slice077.jpg
# │   ├── BraTS20_Training_104_seg-slice077.jpg
# │   ├── BraTS20_Training_104_t1ce-slice077.jpg
# │   ├── BraTS20_Training_104_t1-slice077.jpg
# │   └── BraTS20_Training_104_t2-slice077.jpg
# ├── BraTS20_Training_105
# │   ├── BraTS20_Training_105_flair-slice077.jpg
# │   ├── BraTS20_Training_105_seg-slice077.jpg
# │   ├── BraTS20_Training_105_t1ce-slice077.jpg
# │   ├── BraTS20_Training_105_t1-slice077.jpg
# │   └── BraTS20_Training_105_t2-slice077.jpg
# ├── BraTS20_Training_106
# │   ├── BraTS20_Training_106_flair-slice077.jpg
# │   ├── BraTS20_Training_106_seg-slice077.jpg
# │   ├── BraTS20_Training_106_t1ce-slice077.jpg
# │   ├── BraTS20_Training_106_t1-slice077.jpg
# │   └── BraTS20_Training_106_t2-slice077.jpg
# ├── BraTS20_Training_107
# │   ├── BraTS20_Training_107_flair-slice077.jpg
# │   ├── BraTS20_Training_107_seg-slice077.jpg
# │   ├── BraTS20_Training_107_t1ce-slice077.jpg
# │   ├── BraTS20_Training_107_t1-slice077.jpg
# │   └── BraTS20_Training_107_t2-slice077.jpg
# ├── BraTS20_Training_108
# │   ├── BraTS20_Training_108_flair-slice077.jpg
# │   ├── BraTS20_Training_108_seg-slice077.jpg
# │   ├── BraTS20_Training_108_t1ce-slice077.jpg
# │   ├── BraTS20_Training_108_t1-slice077.jpg
# │   └── BraTS20_Training_108_t2-slice077.jpg
# ├── BraTS20_Training_109
# │   ├── BraTS20_Training_109_flair-slice077.jpg
# │   ├── BraTS20_Training_109_seg-slice077.jpg
# │   ├── BraTS20_Training_109_t1ce-slice077.jpg
# │   ├── BraTS20_Training_109_t1-slice077.jpg
# │   └── BraTS20_Training_109_t2-slice077.jpg
# ├── BraTS20_Training_110
# │   ├── BraTS20_Training_110_flair-slice077.jpg
# │   ├── BraTS20_Training_110_seg-slice077.jpg
# │   ├── BraTS20_Training_110_t1ce-slice077.jpg
# │   ├── BraTS20_Training_110_t1-slice077.jpg
# │   └── BraTS20_Training_110_t2-slice077.jpg
# ├── BraTS20_Training_111
# │   ├── BraTS20_Training_111_flair-slice077.jpg
# │   ├── BraTS20_Training_111_seg-slice077.jpg
# │   ├── BraTS20_Training_111_t1ce-slice077.jpg
# │   ├── BraTS20_Training_111_t1-slice077.jpg
# │   └── BraTS20_Training_111_t2-slice077.jpg
# ├── BraTS20_Training_112
# │   ├── BraTS20_Training_112_flair-slice077.jpg
# │   ├── BraTS20_Training_112_seg-slice077.jpg
# │   ├── BraTS20_Training_112_t1ce-slice077.jpg
# │   ├── BraTS20_Training_112_t1-slice077.jpg
# │   └── BraTS20_Training_112_t2-slice077.jpg
# ├── BraTS20_Training_113
# │   ├── BraTS20_Training_113_flair-slice077.jpg
# │   ├── BraTS20_Training_113_seg-slice077.jpg
# │   ├── BraTS20_Training_113_t1ce-slice077.jpg
# │   ├── BraTS20_Training_113_t1-slice077.jpg
# │   └── BraTS20_Training_113_t2-slice077.jpg
# ├── BraTS20_Training_114
# │   ├── BraTS20_Training_114_flair-slice077.jpg
# │   ├── BraTS20_Training_114_seg-slice077.jpg
# │   ├── BraTS20_Training_114_t1ce-slice077.jpg
# │   ├── BraTS20_Training_114_t1-slice077.jpg
# │   └── BraTS20_Training_114_t2-slice077.jpg
# ├── BraTS20_Training_115
# │   ├── BraTS20_Training_115_flair-slice077.jpg
# │   ├── BraTS20_Training_115_seg-slice077.jpg
# │   ├── BraTS20_Training_115_t1ce-slice077.jpg
# │   ├── BraTS20_Training_115_t1-slice077.jpg
# │   └── BraTS20_Training_115_t2-slice077.jpg
# ├── BraTS20_Training_116
# │   ├── BraTS20_Training_116_flair-slice077.jpg
# │   ├── BraTS20_Training_116_seg-slice077.jpg
# │   ├── BraTS20_Training_116_t1ce-slice077.jpg
# │   ├── BraTS20_Training_116_t1-slice077.jpg
# │   └── BraTS20_Training_116_t2-slice077.jpg
# ├── BraTS20_Training_117
# │   ├── BraTS20_Training_117_flair-slice077.jpg
# │   ├── BraTS20_Training_117_seg-slice077.jpg
# │   ├── BraTS20_Training_117_t1ce-slice077.jpg
# │   ├── BraTS20_Training_117_t1-slice077.jpg
# │   └── BraTS20_Training_117_t2-slice077.jpg
# ├── BraTS20_Training_118
# │   ├── BraTS20_Training_118_flair-slice077.jpg
# │   ├── BraTS20_Training_118_seg-slice077.jpg
# │   ├── BraTS20_Training_118_t1ce-slice077.jpg
# │   ├── BraTS20_Training_118_t1-slice077.jpg
# │   └── BraTS20_Training_118_t2-slice077.jpg
# ├── BraTS20_Training_119
# │   ├── BraTS20_Training_119_flair-slice077.jpg
# │   ├── BraTS20_Training_119_seg-slice077.jpg
# │   ├── BraTS20_Training_119_t1ce-slice077.jpg
# │   ├── BraTS20_Training_119_t1-slice077.jpg
# │   └── BraTS20_Training_119_t2-slice077.jpg
# ├── BraTS20_Training_120
# │   ├── BraTS20_Training_120_flair-slice077.jpg
# │   ├── BraTS20_Training_120_seg-slice077.jpg
# │   ├── BraTS20_Training_120_t1ce-slice077.jpg
# │   ├── BraTS20_Training_120_t1-slice077.jpg
# │   └── BraTS20_Training_120_t2-slice077.jpg
# ├── BraTS20_Training_121
# │   ├── BraTS20_Training_121_flair-slice077.jpg
# │   ├── BraTS20_Training_121_seg-slice077.jpg
# │   ├── BraTS20_Training_121_t1ce-slice077.jpg
# │   ├── BraTS20_Training_121_t1-slice077.jpg
# │   └── BraTS20_Training_121_t2-slice077.jpg
# ├── BraTS20_Training_122
# │   ├── BraTS20_Training_122_flair-slice077.jpg
# │   ├── BraTS20_Training_122_seg-slice077.jpg
# │   ├── BraTS20_Training_122_t1ce-slice077.jpg
# │   ├── BraTS20_Training_122_t1-slice077.jpg
# │   └── BraTS20_Training_122_t2-slice077.jpg
# ├── BraTS20_Training_123
# │   ├── BraTS20_Training_123_flair-slice077.jpg
# │   ├── BraTS20_Training_123_seg-slice077.jpg
# │   ├── BraTS20_Training_123_t1ce-slice077.jpg
# │   ├── BraTS20_Training_123_t1-slice077.jpg
# │   └── BraTS20_Training_123_t2-slice077.jpg
# ├── BraTS20_Training_124
# │   ├── BraTS20_Training_124_flair-slice077.jpg
# │   ├── BraTS20_Training_124_seg-slice077.jpg
# │   ├── BraTS20_Training_124_t1ce-slice077.jpg
# │   ├── BraTS20_Training_124_t1-slice077.jpg
# │   └── BraTS20_Training_124_t2-slice077.jpg
# ├── BraTS20_Training_125
# │   ├── BraTS20_Training_125_flair-slice077.jpg
# │   ├── BraTS20_Training_125_seg-slice077.jpg
# │   ├── BraTS20_Training_125_t1ce-slice077.jpg
# │   ├── BraTS20_Training_125_t1-slice077.jpg
# │   └── BraTS20_Training_125_t2-slice077.jpg
# ├── BraTS20_Training_126
# │   ├── BraTS20_Training_126_flair-slice077.jpg
# │   ├── BraTS20_Training_126_seg-slice077.jpg
# │   ├── BraTS20_Training_126_t1ce-slice077.jpg
# │   ├── BraTS20_Training_126_t1-slice077.jpg
# │   └── BraTS20_Training_126_t2-slice077.jpg
# ├── BraTS20_Training_127
# │   ├── BraTS20_Training_127_flair-slice077.jpg
# │   ├── BraTS20_Training_127_seg-slice077.jpg
# │   ├── BraTS20_Training_127_t1ce-slice077.jpg
# │   ├── BraTS20_Training_127_t1-slice077.jpg
# │   └── BraTS20_Training_127_t2-slice077.jpg
# ├── BraTS20_Training_128
# │   ├── BraTS20_Training_128_flair-slice077.jpg
# │   ├── BraTS20_Training_128_seg-slice077.jpg
# │   ├── BraTS20_Training_128_t1ce-slice077.jpg
# │   ├── BraTS20_Training_128_t1-slice077.jpg
# │   └── BraTS20_Training_128_t2-slice077.jpg
# ├── BraTS20_Training_129
# │   ├── BraTS20_Training_129_flair-slice077.jpg
# │   ├── BraTS20_Training_129_seg-slice077.jpg
# │   ├── BraTS20_Training_129_t1ce-slice077.jpg
# │   ├── BraTS20_Training_129_t1-slice077.jpg
# │   └── BraTS20_Training_129_t2-slice077.jpg
# ├── BraTS20_Training_130
# │   ├── BraTS20_Training_130_flair-slice077.jpg
# │   ├── BraTS20_Training_130_seg-slice077.jpg
# │   ├── BraTS20_Training_130_t1ce-slice077.jpg
# │   ├── BraTS20_Training_130_t1-slice077.jpg
# │   └── BraTS20_Training_130_t2-slice077.jpg
# ├── BraTS20_Training_131
# │   ├── BraTS20_Training_131_flair-slice077.jpg
# │   ├── BraTS20_Training_131_seg-slice077.jpg
# │   ├── BraTS20_Training_131_t1ce-slice077.jpg
# │   ├── BraTS20_Training_131_t1-slice077.jpg
# │   └── BraTS20_Training_131_t2-slice077.jpg
# ├── BraTS20_Training_132
# │   ├── BraTS20_Training_132_flair-slice077.jpg
# │   ├── BraTS20_Training_132_seg-slice077.jpg
# │   ├── BraTS20_Training_132_t1ce-slice077.jpg
# │   ├── BraTS20_Training_132_t1-slice077.jpg
# │   └── BraTS20_Training_132_t2-slice077.jpg
# ├── BraTS20_Training_133
# │   ├── BraTS20_Training_133_flair-slice077.jpg
# │   ├── BraTS20_Training_133_seg-slice077.jpg
# │   ├── BraTS20_Training_133_t1ce-slice077.jpg
# │   ├── BraTS20_Training_133_t1-slice077.jpg
# │   └── BraTS20_Training_133_t2-slice077.jpg
# ├── BraTS20_Training_134
# │   ├── BraTS20_Training_134_flair-slice077.jpg
# │   ├── BraTS20_Training_134_seg-slice077.jpg
# │   ├── BraTS20_Training_134_t1ce-slice077.jpg
# │   ├── BraTS20_Training_134_t1-slice077.jpg
# │   └── BraTS20_Training_134_t2-slice077.jpg
# ├── BraTS20_Training_135
# │   ├── BraTS20_Training_135_flair-slice077.jpg
# │   ├── BraTS20_Training_135_seg-slice077.jpg
# │   ├── BraTS20_Training_135_t1ce-slice077.jpg
# │   ├── BraTS20_Training_135_t1-slice077.jpg
# │   └── BraTS20_Training_135_t2-slice077.jpg
# ├── BraTS20_Training_136
# │   ├── BraTS20_Training_136_flair-slice077.jpg
# │   ├── BraTS20_Training_136_seg-slice077.jpg
# │   ├── BraTS20_Training_136_t1ce-slice077.jpg
# │   ├── BraTS20_Training_136_t1-slice077.jpg
# │   └── BraTS20_Training_136_t2-slice077.jpg
# ├── BraTS20_Training_137
# │   ├── BraTS20_Training_137_flair-slice077.jpg
# │   ├── BraTS20_Training_137_seg-slice077.jpg
# │   ├── BraTS20_Training_137_t1ce-slice077.jpg
# │   ├── BraTS20_Training_137_t1-slice077.jpg
# │   └── BraTS20_Training_137_t2-slice077.jpg
# ├── BraTS20_Training_138
# │   ├── BraTS20_Training_138_flair-slice077.jpg
# │   ├── BraTS20_Training_138_seg-slice077.jpg
# │   ├── BraTS20_Training_138_t1ce-slice077.jpg
# │   ├── BraTS20_Training_138_t1-slice077.jpg
# │   └── BraTS20_Training_138_t2-slice077.jpg
# ├── BraTS20_Training_139
# │   ├── BraTS20_Training_139_flair-slice077.jpg
# │   ├── BraTS20_Training_139_seg-slice077.jpg
# │   ├── BraTS20_Training_139_t1ce-slice077.jpg
# │   ├── BraTS20_Training_139_t1-slice077.jpg
# │   └── BraTS20_Training_139_t2-slice077.jpg
# ├── BraTS20_Training_140
# │   ├── BraTS20_Training_140_flair-slice077.jpg
# │   ├── BraTS20_Training_140_seg-slice077.jpg
# │   ├── BraTS20_Training_140_t1ce-slice077.jpg
# │   ├── BraTS20_Training_140_t1-slice077.jpg
# │   └── BraTS20_Training_140_t2-slice077.jpg
# ├── BraTS20_Training_141
# │   ├── BraTS20_Training_141_flair-slice077.jpg
# │   ├── BraTS20_Training_141_seg-slice077.jpg
# │   ├── BraTS20_Training_141_t1ce-slice077.jpg
# │   ├── BraTS20_Training_141_t1-slice077.jpg
# │   └── BraTS20_Training_141_t2-slice077.jpg
# ├── BraTS20_Training_142
# │   ├── BraTS20_Training_142_flair-slice077.jpg
# │   ├── BraTS20_Training_142_seg-slice077.jpg
# │   ├── BraTS20_Training_142_t1ce-slice077.jpg
# │   ├── BraTS20_Training_142_t1-slice077.jpg
# │   └── BraTS20_Training_142_t2-slice077.jpg
# ├── BraTS20_Training_143
# │   ├── BraTS20_Training_143_flair-slice077.jpg
# │   ├── BraTS20_Training_143_seg-slice077.jpg
# │   ├── BraTS20_Training_143_t1ce-slice077.jpg
# │   ├── BraTS20_Training_143_t1-slice077.jpg
# │   └── BraTS20_Training_143_t2-slice077.jpg
# ├── BraTS20_Training_144
# │   ├── BraTS20_Training_144_flair-slice077.jpg
# │   ├── BraTS20_Training_144_seg-slice077.jpg
# │   ├── BraTS20_Training_144_t1ce-slice077.jpg
# │   ├── BraTS20_Training_144_t1-slice077.jpg
# │   └── BraTS20_Training_144_t2-slice077.jpg
# ├── BraTS20_Training_145
# │   ├── BraTS20_Training_145_flair-slice077.jpg
# │   ├── BraTS20_Training_145_seg-slice077.jpg
# │   ├── BraTS20_Training_145_t1ce-slice077.jpg
# │   ├── BraTS20_Training_145_t1-slice077.jpg
# │   └── BraTS20_Training_145_t2-slice077.jpg
# ├── BraTS20_Training_146
# │   ├── BraTS20_Training_146_flair-slice077.jpg
# │   ├── BraTS20_Training_146_seg-slice077.jpg
# │   ├── BraTS20_Training_146_t1ce-slice077.jpg
# │   ├── BraTS20_Training_146_t1-slice077.jpg
# │   └── BraTS20_Training_146_t2-slice077.jpg
# ├── BraTS20_Training_147
# │   ├── BraTS20_Training_147_flair-slice077.jpg
# │   ├── BraTS20_Training_147_seg-slice077.jpg
# │   ├── BraTS20_Training_147_t1ce-slice077.jpg
# │   ├── BraTS20_Training_147_t1-slice077.jpg
# │   └── BraTS20_Training_147_t2-slice077.jpg
# ├── BraTS20_Training_148
# │   ├── BraTS20_Training_148_flair-slice077.jpg
# │   ├── BraTS20_Training_148_seg-slice077.jpg
# │   ├── BraTS20_Training_148_t1ce-slice077.jpg
# │   ├── BraTS20_Training_148_t1-slice077.jpg
# │   └── BraTS20_Training_148_t2-slice077.jpg
# ├── BraTS20_Training_149
# │   ├── BraTS20_Training_149_flair-slice077.jpg
# │   ├── BraTS20_Training_149_seg-slice077.jpg
# │   ├── BraTS20_Training_149_t1ce-slice077.jpg
# │   ├── BraTS20_Training_149_t1-slice077.jpg
# │   └── BraTS20_Training_149_t2-slice077.jpg
# ├── BraTS20_Training_150
# │   ├── BraTS20_Training_150_flair-slice077.jpg
# │   ├── BraTS20_Training_150_seg-slice077.jpg
# │   ├── BraTS20_Training_150_t1ce-slice077.jpg
# │   ├── BraTS20_Training_150_t1-slice077.jpg
# │   └── BraTS20_Training_150_t2-slice077.jpg
# ├── BraTS20_Training_151
# │   ├── BraTS20_Training_151_flair-slice077.jpg
# │   ├── BraTS20_Training_151_seg-slice077.jpg
# │   ├── BraTS20_Training_151_t1ce-slice077.jpg
# │   ├── BraTS20_Training_151_t1-slice077.jpg
# │   └── BraTS20_Training_151_t2-slice077.jpg
# ├── BraTS20_Training_152
# │   ├── BraTS20_Training_152_flair-slice077.jpg
# │   ├── BraTS20_Training_152_seg-slice077.jpg
# │   ├── BraTS20_Training_152_t1ce-slice077.jpg
# │   ├── BraTS20_Training_152_t1-slice077.jpg
# │   └── BraTS20_Training_152_t2-slice077.jpg
# ├── BraTS20_Training_153
# │   ├── BraTS20_Training_153_flair-slice077.jpg
# │   ├── BraTS20_Training_153_seg-slice077.jpg
# │   ├── BraTS20_Training_153_t1ce-slice077.jpg
# │   ├── BraTS20_Training_153_t1-slice077.jpg
# │   └── BraTS20_Training_153_t2-slice077.jpg
# ├── BraTS20_Training_154
# │   ├── BraTS20_Training_154_flair-slice077.jpg
# │   ├── BraTS20_Training_154_seg-slice077.jpg
# │   ├── BraTS20_Training_154_t1ce-slice077.jpg
# │   ├── BraTS20_Training_154_t1-slice077.jpg
# │   └── BraTS20_Training_154_t2-slice077.jpg
# ├── BraTS20_Training_155
# │   ├── BraTS20_Training_155_flair-slice077.jpg
# │   ├── BraTS20_Training_155_seg-slice077.jpg
# │   ├── BraTS20_Training_155_t1ce-slice077.jpg
# │   ├── BraTS20_Training_155_t1-slice077.jpg
# │   └── BraTS20_Training_155_t2-slice077.jpg
# ├── BraTS20_Training_156
# │   ├── BraTS20_Training_156_flair-slice077.jpg
# │   ├── BraTS20_Training_156_seg-slice077.jpg
# │   ├── BraTS20_Training_156_t1ce-slice077.jpg
# │   ├── BraTS20_Training_156_t1-slice077.jpg
# │   └── BraTS20_Training_156_t2-slice077.jpg
# ├── BraTS20_Training_157
# │   ├── BraTS20_Training_157_flair-slice077.jpg
# │   ├── BraTS20_Training_157_seg-slice077.jpg
# │   ├── BraTS20_Training_157_t1ce-slice077.jpg
# │   ├── BraTS20_Training_157_t1-slice077.jpg
# │   └── BraTS20_Training_157_t2-slice077.jpg
# ├── BraTS20_Training_158
# │   ├── BraTS20_Training_158_flair-slice077.jpg
# │   ├── BraTS20_Training_158_seg-slice077.jpg
# │   ├── BraTS20_Training_158_t1ce-slice077.jpg
# │   ├── BraTS20_Training_158_t1-slice077.jpg
# │   └── BraTS20_Training_158_t2-slice077.jpg
# ├── BraTS20_Training_159
# │   ├── BraTS20_Training_159_flair-slice077.jpg
# │   ├── BraTS20_Training_159_seg-slice077.jpg
# │   ├── BraTS20_Training_159_t1ce-slice077.jpg
# │   ├── BraTS20_Training_159_t1-slice077.jpg
# │   └── BraTS20_Training_159_t2-slice077.jpg
# ├── BraTS20_Training_160
# │   ├── BraTS20_Training_160_flair-slice077.jpg
# │   ├── BraTS20_Training_160_seg-slice077.jpg
# │   ├── BraTS20_Training_160_t1ce-slice077.jpg
# │   ├── BraTS20_Training_160_t1-slice077.jpg
# │   └── BraTS20_Training_160_t2-slice077.jpg
# ├── BraTS20_Training_161
# │   ├── BraTS20_Training_161_flair-slice077.jpg
# │   ├── BraTS20_Training_161_seg-slice077.jpg
# │   ├── BraTS20_Training_161_t1ce-slice077.jpg
# │   ├── BraTS20_Training_161_t1-slice077.jpg
# │   └── BraTS20_Training_161_t2-slice077.jpg
# ├── BraTS20_Training_162
# │   ├── BraTS20_Training_162_flair-slice077.jpg
# │   ├── BraTS20_Training_162_seg-slice077.jpg
# │   ├── BraTS20_Training_162_t1ce-slice077.jpg
# │   ├── BraTS20_Training_162_t1-slice077.jpg
# │   └── BraTS20_Training_162_t2-slice077.jpg
# ├── BraTS20_Training_163
# │   ├── BraTS20_Training_163_flair-slice077.jpg
# │   ├── BraTS20_Training_163_seg-slice077.jpg
# │   ├── BraTS20_Training_163_t1ce-slice077.jpg
# │   ├── BraTS20_Training_163_t1-slice077.jpg
# │   └── BraTS20_Training_163_t2-slice077.jpg
# ├── BraTS20_Training_164
# │   ├── BraTS20_Training_164_flair-slice077.jpg
# │   ├── BraTS20_Training_164_seg-slice077.jpg
# │   ├── BraTS20_Training_164_t1ce-slice077.jpg
# │   ├── BraTS20_Training_164_t1-slice077.jpg
# │   └── BraTS20_Training_164_t2-slice077.jpg
# ├── BraTS20_Training_165
# │   ├── BraTS20_Training_165_flair-slice077.jpg
# │   ├── BraTS20_Training_165_seg-slice077.jpg
# │   ├── BraTS20_Training_165_t1ce-slice077.jpg
# │   ├── BraTS20_Training_165_t1-slice077.jpg
# │   └── BraTS20_Training_165_t2-slice077.jpg
# ├── BraTS20_Training_166
# │   ├── BraTS20_Training_166_flair-slice077.jpg
# │   ├── BraTS20_Training_166_seg-slice077.jpg
# │   ├── BraTS20_Training_166_t1ce-slice077.jpg
# │   ├── BraTS20_Training_166_t1-slice077.jpg
# │   └── BraTS20_Training_166_t2-slice077.jpg
# ├── BraTS20_Training_167
# │   ├── BraTS20_Training_167_flair-slice077.jpg
# │   ├── BraTS20_Training_167_seg-slice077.jpg
# │   ├── BraTS20_Training_167_t1ce-slice077.jpg
# │   ├── BraTS20_Training_167_t1-slice077.jpg
# │   └── BraTS20_Training_167_t2-slice077.jpg
# ├── BraTS20_Training_168
# │   ├── BraTS20_Training_168_flair-slice077.jpg
# │   ├── BraTS20_Training_168_seg-slice077.jpg
# │   ├── BraTS20_Training_168_t1ce-slice077.jpg
# │   ├── BraTS20_Training_168_t1-slice077.jpg
# │   └── BraTS20_Training_168_t2-slice077.jpg
# ├── BraTS20_Training_169
# │   ├── BraTS20_Training_169_flair-slice077.jpg
# │   ├── BraTS20_Training_169_seg-slice077.jpg
# │   ├── BraTS20_Training_169_t1ce-slice077.jpg
# │   ├── BraTS20_Training_169_t1-slice077.jpg
# │   └── BraTS20_Training_169_t2-slice077.jpg
# └── BraTS20_Training_170
#     ├── BraTS20_Training_170_flair-slice077.jpg
#     ├── BraTS20_Training_170_seg-slice077.jpg
#     ├── BraTS20_Training_170_t1ce-slice077.jpg
#     ├── BraTS20_Training_170_t1-slice077.jpg
#     └── BraTS20_Training_170_t2-slice077.jpg
#
# 170 directories, 850 files

# %%
# Učitaj CSV datoteku
survival_info = pd.read_csv('/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/survival_info.csv')
survival_info.head(5)
# Out:
#               Brats20ID     Age Survival_days Extent_of_Resection
# 0  BraTS20_Training_001  60.463           289                 GTR
# 1  BraTS20_Training_002  52.263           616                 GTR
# 2  BraTS20_Training_003  54.301           464                 GTR
# 3  BraTS20_Training_004  39.068           788                 GTR
# 4  BraTS20_Training_005  68.493           465                 GTR

# %%
name_mapping = pd.read_csv('/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData/name_mapping.csv')
name_mapping.head(5)
# Out:
#   Grade BraTS_2017_subject_ID BraTS_2018_subject_ID TCGA_TCIA_subject_ID  \
# 0   HGG   Brats17_CBICA_AAB_1   Brats18_CBICA_AAB_1                  NaN
# 1   HGG   Brats17_CBICA_AAG_1   Brats18_CBICA_AAG_1                  NaN
# 2   HGG   Brats17_CBICA_AAL_1   Brats18_CBICA_AAL_1                  NaN
# 3   HGG   Brats17_CBICA_AAP_1   Brats18_CBICA_AAP_1                  NaN
# 4   HGG   Brats17_CBICA_ABB_1   Brats18_CBICA_ABB_1                  NaN
#
#   BraTS_2019_subject_ID BraTS_2020_subject_ID
# 0   BraTS19_CBICA_AAB_1  BraTS20_Training_001
# 1   BraTS19_CBICA_AAG_1  BraTS20_Training_002
# 2   BraTS19_CBICA_AAL_1  BraTS20_Training_003
# 3   BraTS19_CBICA_AAP_1  BraTS20_Training_004
# 4   BraTS19_CBICA_ABB_1  BraTS20_Training_005

# %%
# Povezivanje podataka prema različitim ključevima
merged_data = pd.merge(name_mapping, survival_info, left_on="BraTS_2020_subject_ID", right_on="Brats20ID", how="inner")
merged_data.head(5)
# Out:
#   Grade BraTS_2017_subject_ID BraTS_2018_subject_ID TCGA_TCIA_subject_ID  \
# 0   HGG   Brats17_CBICA_AAB_1   Brats18_CBICA_AAB_1                  NaN
# 1   HGG   Brats17_CBICA_AAG_1   Brats18_CBICA_AAG_1                  NaN
# 2   HGG   Brats17_CBICA_AAL_1   Brats18_CBICA_AAL_1                  NaN
# 3   HGG   Brats17_CBICA_AAP_1   Brats18_CBICA_AAP_1                  NaN
# 4   HGG   Brats17_CBICA_ABB_1   Brats18_CBICA_ABB_1                  NaN
#
#   BraTS_2019_subject_ID BraTS_2020_subject_ID             Brats20ID     Age  \
# 0   BraTS19_CBICA_AAB_1  BraTS20_Training_001  BraTS20_Training_001  60.463
# 1   BraTS19_CBICA_AAG_1  BraTS20_Training_002  BraTS20_Training_002  52.263
# 2   BraTS19_CBICA_AAL_1  BraTS20_Training_003  BraTS20_Training_003  54.301
# 3   BraTS19_CBICA_AAP_1  BraTS20_Training_004  BraTS20_Training_004  39.068
# 4   BraTS19_CBICA_ABB_1  BraTS20_Training_005  BraTS20_Training_005  68.493
#
#   Survival_days Extent_of_Resection
# 0           289                 GTR
# 1           616                 GTR
# 2           464                 GTR
# 3           788                 GTR
# 4           465                 GTR

# %%
main_output_directory = '/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData_jpg/'

# Lista svih direktorija pacijenata u glavnom izlaznom direktoriju
patient_directories = [d for d in os.listdir(main_output_directory) if os.path.isdir(os.path.join(main_output_directory, d))]

# Nasumično odaberite 3 pacijenta
selected_patients = np.random.choice(patient_directories, size=3, replace=False)

# Funkcija za izdvajanje modality type iz naziva slike
def extract_modality_type(file_name):
    return file_name.split('_')[-1].split('-')[0]

# Prikazi slike za svakog odabrana pacijenta
for selected_patient in selected_patients:
    # Konstruiraj putanju do izlaznog direktorija odabranog pacijenta
    selected_patient_output_directory = os.path.join(main_output_directory, selected_patient)

    # Lista svih datoteka slika u izlaznom direktoriju odabranog pacijenta
    image_files = [f for f in os.listdir(selected_patient_output_directory) if f.endswith('.jpg')]

    # Sortiraj slike prema redoslijedu T1, T1CE, T2, FLAIR, seg
    image_files.sort(key=lambda x: ['t1', 't1ce', 't2', 'flair', 'seg'].index(extract_modality_type(x.lower())))

    # Prikazi svaku odabrane slike s povećanim razmakom
    plt.figure(figsize=(15, 3))
    for i, image_file in enumerate(image_files):
        # Izdvoji modality type pomoću funkcije
        modality_type = extract_modality_type(image_file)

        # Učitaj sliku
        img_path = os.path.join(selected_patient_output_directory, image_file)
        img = np.array(Image.open(img_path))

        plt.subplot(1, len(image_files), i + 1)
        plt.imshow(img, cmap='bone')
        plt.axis('off')
        plt.title(modality_type)

    plt.suptitle(f"Patient: {selected_patient}", fontsize=12)
    plt.show()

# %%
import os
import pandas as pd
import numpy as np
from PIL import Image
from sklearn.model_selection import train_test_split

# Učitajte spojeni skup podataka
merged_data = pd.merge(name_mapping, survival_info, left_on="BraTS_2020_subject_ID", right_on="Brats20ID", how="inner")

# Postavite putanju do direktorija sa slikama
image_dir = '/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData_jpg/'

# Inicijalizirajte prazne liste za podatke i oznake
data = []
labels = []

for index, row in merged_data.iterrows():
    # Dobivanje ID-a pacijenta
    patient_id = row['BraTS_2020_subject_ID']

    # Konstruirajte putanju do direktorija pacijenta sa slikama
    patient_image_dir = os.path.join(image_dir, patient_id)

    # Provjerite jesu li poddirektoriji prisutni
    if os.path.isdir(patient_image_dir):
        try:
            # Učitajte slike i dodajte ih u podatke i oznake
            img_flair = np.array(Image.open(os.path.join(patient_image_dir, f'{patient_id}_flair-slice077.jpg')))
            img_t1 = np.array(Image.open(os.path.join(patient_image_dir, f'{patient_id}_t1-slice077.jpg')))
            img_t1ce = np.array(Image.open(os.path.join(patient_image_dir, f'{patient_id}_t1ce-slice077.jpg')))
            img_t2 = np.array(Image.open(os.path.join(patient_image_dir, f'{patient_id}_t2-slice077.jpg')))
            img_seg = np.array(Image.open(os.path.join(patient_image_dir, f'{patient_id}_seg-slice077.jpg')))

            # Dodajte slike u podatke i oznake
            data.append([img_flair, img_t1, img_t1ce, img_t2])
            labels.append(img_seg)

            # Ispis ID-a pacijenta ako je uspješno učitan
            print(f"Učitan pacijent: {patient_id}")

        except Exception as e:
            print(f"Greška pri učitavanju slika za pacijenta {patient_id}: {e}")

# Pretvorite liste u numpy nizove
data = np.array(data)
labels = np.array(labels)

# Provjerite dimenzije
print("Dimenzije skupa za učenje:", data.shape, labels.shape)
# Out:
# Učitan pacijent: BraTS20_Training_001
# Učitan pacijent: BraTS20_Training_002
# Učitan pacijent: BraTS20_Training_003
# Učitan pacijent: BraTS20_Training_004
# Učitan pacijent: BraTS20_Training_005
# Učitan pacijent: BraTS20_Training_006
# Učitan pacijent: BraTS20_Training_007
# Učitan pacijent: BraTS20_Training_008
# Učitan pacijent: BraTS20_Training_009
# Učitan pacijent: BraTS20_Training_010
# Učitan pacijent: BraTS20_Training_011
# Učitan pacijent: BraTS20_Training_012
# Učitan pacijent: BraTS20_Training_013
# Učitan pacijent: BraTS20_Training_014
# Učitan pacijent: BraTS20_Training_015
# Učitan pacijent: BraTS20_Training_016
# Učitan pacijent: BraTS20_Training_017
# Učitan pacijent: BraTS20_Training_018
# Učitan pacijent: BraTS20_Training_019
# Učitan pacijent: BraTS20_Training_020
# Učitan pacijent: BraTS20_Training_021
# Učitan pacijent: BraTS20_Training_022
# Učitan pacijent: BraTS20_Training_023
# Učitan pacijent: BraTS20_Training_024
# Učitan pacijent: BraTS20_Training_025
# Učitan pacijent: BraTS20_Training_026
# Učitan pacijent: BraTS20_Training_027
# Učitan pacijent: BraTS20_Training_028
# Učitan pacijent: BraTS20_Training_029
# Učitan pacijent: BraTS20_Training_030
# Učitan pacijent: BraTS20_Training_031
# Učitan pacijent: BraTS20_Training_032
# Učitan pacijent: BraTS20_Training_033
# Učitan pacijent: BraTS20_Training_034
# Učitan pacijent: BraTS20_Training_035
# Učitan pacijent: BraTS20_Training_036
# Učitan pacijent: BraTS20_Training_037
# Učitan pacijent: BraTS20_Training_038
# Učitan pacijent: BraTS20_Training_039
# Učitan pacijent: BraTS20_Training_040
# Učitan pacijent: BraTS20_Training_041
# Učitan pacijent: BraTS20_Training_042
# Učitan pacijent: BraTS20_Training_043
# Učitan pacijent: BraTS20_Training_044
# Učitan pacijent: BraTS20_Training_045
# Učitan pacijent: BraTS20_Training_046
# Učitan pacijent: BraTS20_Training_047
# Učitan pacijent: BraTS20_Training_048
# Učitan pacijent: BraTS20_Training_049
# Učitan pacijent: BraTS20_Training_050
# Učitan pacijent: BraTS20_Training_051
# Učitan pacijent: BraTS20_Training_052
# Učitan pacijent: BraTS20_Training_053
# Učitan pacijent: BraTS20_Training_054
# Učitan pacijent: BraTS20_Training_055
# Učitan pacijent: BraTS20_Training_056
# Učitan pacijent: BraTS20_Training_057
# Učitan pacijent: BraTS20_Training_058
# Učitan pacijent: BraTS20_Training_059
# Učitan pacijent: BraTS20_Training_060
# Učitan pacijent: BraTS20_Training_061
# Učitan pacijent: BraTS20_Training_062
# Učitan pacijent: BraTS20_Training_063
# Učitan pacijent: BraTS20_Training_064
# Učitan pacijent: BraTS20_Training_065
# Učitan pacijent: BraTS20_Training_066
# Učitan pacijent: BraTS20_Training_067
# Učitan pacijent: BraTS20_Training_068
# Učitan pacijent: BraTS20_Training_069
# Učitan pacijent: BraTS20_Training_070
# Učitan pacijent: BraTS20_Training_071
# Učitan pacijent: BraTS20_Training_072
# Učitan pacijent: BraTS20_Training_073
# Učitan pacijent: BraTS20_Training_074
# Učitan pacijent: BraTS20_Training_075
# Učitan pacijent: BraTS20_Training_076
# Učitan pacijent: BraTS20_Training_077
# Učitan pacijent: BraTS20_Training_078
# Učitan pacijent: BraTS20_Training_079
# Učitan pacijent: BraTS20_Training_080
# Učitan pacijent: BraTS20_Training_081
# Učitan pacijent: BraTS20_Training_082
# Učitan pacijent: BraTS20_Training_083
# Učitan pacijent: BraTS20_Training_084
# Učitan pacijent: BraTS20_Training_085
# Učitan pacijent: BraTS20_Training_086
# Učitan pacijent: BraTS20_Training_087
# Učitan pacijent: BraTS20_Training_088
# Učitan pacijent: BraTS20_Training_089
# Učitan pacijent: BraTS20_Training_090
# Učitan pacijent: BraTS20_Training_091
# Učitan pacijent: BraTS20_Training_092
# Učitan pacijent: BraTS20_Training_093
# Učitan pacijent: BraTS20_Training_094
# Učitan pacijent: BraTS20_Training_095
# Učitan pacijent: BraTS20_Training_096
# Učitan pacijent: BraTS20_Training_097
# Učitan pacijent: BraTS20_Training_098
# Učitan pacijent: BraTS20_Training_099
# Učitan pacijent: BraTS20_Training_100
# Učitan pacijent: BraTS20_Training_101
# Učitan pacijent: BraTS20_Training_102
# Učitan pacijent: BraTS20_Training_103
# Učitan pacijent: BraTS20_Training_104
# Učitan pacijent: BraTS20_Training_105
# Učitan pacijent: BraTS20_Training_106
# Učitan pacijent: BraTS20_Training_107
# Učitan pacijent: BraTS20_Training_108
# Učitan pacijent: BraTS20_Training_109
# Učitan pacijent: BraTS20_Training_110
# Učitan pacijent: BraTS20_Training_111
# Učitan pacijent: BraTS20_Training_112
# Učitan pacijent: BraTS20_Training_113
# Učitan pacijent: BraTS20_Training_114
# Učitan pacijent: BraTS20_Training_115
# Učitan pacijent: BraTS20_Training_116
# Učitan pacijent: BraTS20_Training_117
# Učitan pacijent: BraTS20_Training_118
# Učitan pacijent: BraTS20_Training_119
# Učitan pacijent: BraTS20_Training_120
# Učitan pacijent: BraTS20_Training_121
# Učitan pacijent: BraTS20_Training_122
# Učitan pacijent: BraTS20_Training_123
# Učitan pacijent: BraTS20_Training_124
# Učitan pacijent: BraTS20_Training_125
# Učitan pacijent: BraTS20_Training_126
# Učitan pacijent: BraTS20_Training_127
# Učitan pacijent: BraTS20_Training_128
# Učitan pacijent: BraTS20_Training_129
# Učitan pacijent: BraTS20_Training_145
# Učitan pacijent: BraTS20_Training_147
# Učitan pacijent: BraTS20_Training_151
# Učitan pacijent: BraTS20_Training_152
# Učitan pacijent: BraTS20_Training_153
# Učitan pacijent: BraTS20_Training_154
# Učitan pacijent: BraTS20_Training_157
# Učitan pacijent: BraTS20_Training_158
# Učitan pacijent: BraTS20_Training_159
# Učitan pacijent: BraTS20_Training_160
# Učitan pacijent: BraTS20_Training_161
# Učitan pacijent: BraTS20_Training_162
# Učitan pacijent: BraTS20_Training_163
# Učitan pacijent: BraTS20_Training_164
# Učitan pacijent: BraTS20_Training_165
# Učitan pacijent: BraTS20_Training_166
# Učitan pacijent: BraTS20_Training_167
# Učitan pacijent: BraTS20_Training_168
# Učitan pacijent: BraTS20_Training_169
# Učitan pacijent: BraTS20_Training_170
# Dimenzije skupa za učenje: (149, 4, 240, 240, 3) (149, 240, 240, 3)

# %%
# Prikazivanje minimalnih i maksimalnih vrijednosti piksela u slikama
print("Min i Max vrijednosti prije normalizacije:")
print("Flair:", np.min(data[:, 0]), np.max(data[:, 0]))
print("T1:", np.min(data[:, 1]), np.max(data[:, 1]))
print("T1CE:", np.min(data[:, 2]), np.max(data[:, 2]))
print("T2:", np.min(data[:, 3]), np.max(data[:, 3]))
print("Segmentation:", np.min(labels), np.max(labels))
# Out:
# Min i Max vrijednosti prije normalizacije:
# Flair: 0 255
# T1: 0 255
# T1CE: 0 255
# T2: 0 255
# Segmentation: 0 255

# %%
# Normalizacija na raspon [0, 1]
data_normalized = data / 255.0
labels_normalized = labels / 255.0

# %%
# Prikazivanje minimalnih i maksimalnih vrijednosti piksela u slikama
print("Min i Max vrijednosti prije normalizacije:")
print("Flair:", np.min(data_normalized[:, 0]), np.max(data_normalized[:, 0]))
print("T1:", np.min(data_normalized[:, 1]), np.max(data_normalized[:, 1]))
print("T1CE:", np.min(data_normalized[:, 2]), np.max(data_normalized[:, 2]))
print("T2:", np.min(data_normalized[:, 3]), np.max(data_normalized[:, 3]))
print("Segmentation:", np.min(labels_normalized), np.max(labels_normalized))
# Out:
# Min i Max vrijednosti prije normalizacije:
# Flair: 0.0 1.0
# T1: 0.0 1.0
# T1CE: 0.0 1.0
# T2: 0.0 1.0
# Segmentation: 0.0 1.0

# %%
import torch
from torch.utils.data import Dataset

class BrainTumorDataset(Dataset):
    def __init__(self, data, labels, transform=None):
        self.data = data
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = {
            'image': self.data[idx].transpose(0, 3, 1, 2),  # Transponirajte dimenzije
            'mask': self.labels[idx]
        }

        if self.transform:
            sample = self.transform(sample)

        return sample

# %%
# Kreiranje instance klase BraTSDataset
brats_dataset = BrainTumorDataset(data_normalized, labels_normalized)

# Prikazivanje nekoliko uzoraka iz dataseta
for i in range(5):
    sample = brats_dataset[i]
    print(f"Uzorak {i + 1}:")
    print("Dimenzije slike:", sample['image'].shape)
    print("Dimenzije maske:", sample['mask'].shape)
    print("--------------------------------------------------")
# Out:
# Uzorak 1:
# Dimenzije slike: (4, 3, 240, 240)
# Dimenzije maske: (240, 240, 3)
# --------------------------------------------------
# Uzorak 2:
# Dimenzije slike: (4, 3, 240, 240)
# Dimenzije maske: (240, 240, 3)
# --------------------------------------------------
# Uzorak 3:
# Dimenzije slike: (4, 3, 240, 240)
# Dimenzije maske: (240, 240, 3)
# --------------------------------------------------
# Uzorak 4:
# Dimenzije slike: (4, 3, 240, 240)
# Dimenzije maske: (240, 240, 3)
# --------------------------------------------------
# Uzorak 5:
# Dimenzije slike: (4, 3, 240, 240)
# Dimenzije maske: (240, 240, 3)
# --------------------------------------------------

# %%
from sklearn.model_selection import train_test_split

# Podijeli podatke na skup za trening i skup za validaciju
train_data, val_data, train_labels, val_labels = train_test_split(data_normalized, labels_normalized, test_size=0.2, random_state=42)

# Provjerite dimenzije podataka za trening i validaciju
print("Dimenzije skupa za trening:", train_data.shape, train_labels.shape)
print("Dimenzije skupa za validaciju:", val_data.shape, val_labels.shape)

# Kreirajte DataLoader-e za trening i validaciju
batch_size = 32
train_dataset = BrainTumorDataset(train_data, train_labels)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = BrainTumorDataset(val_data, val_labels)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Dimenzije skupa za trening: (119, 4, 240, 240, 3) (119, 240, 240, 3)
# Dimenzije skupa za validaciju: (30, 4, 240, 240, 3) (30, 240, 240, 3)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    print("using gpu")
else:
    print("using cpu")
# Out:
# using cpu

# %%
import torch
import torch.nn as nn

class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()

        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(4, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(64, 64, kernel_size=2, stride=2),
            nn.Conv2d(64, 1, kernel_size=1)  # Output layer with 1 channel for segmentation
        )

    def forward(self, x):
        # Encoder pass
        x1 = self.encoder(x)
        # Decoder pass
        x2 = self.decoder(x1)
        return x2

# Create an instance of the UNet model
model = UNet()

# Print the model architecture
print(model)
# Out:
# UNet(
#   (encoder): Sequential(
#     (0): Conv2d(4, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): ConvTranspose2d(64, 64, kernel_size=(2, 2), stride=(2, 2))
#     (5): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %% [markdown]
# # **NESTO**

# %%
imgs_dir='/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData_jpg/'
all_dirs = glob (f'{imgs_dir}/*')
len (all_dirs)
all_dirs.sort()
# test_dirs = np.copy(all_dirs[45000:])
# all_dirs = all_dirs[:45000]
# len(all_dirs), all_dirs[:10]

# %%
def shuffle_split (all_dirs, val_pct = 0.15, seed = 99):
    """ shuffling dataset with random state and split to train and valid """
    n_val = int (len (all_dirs) * val_pct)
    np.random.seed (seed)
    idx = np.random.permutation (len (all_dirs))
    all_dirs = np.array (all_dirs) [idx]

    return all_dirs [n_val:], all_dirs [:n_val]

train_dirs, valid_dirs = shuffle_split (all_dirs, seed = 1)
len(valid_dirs), len(train_dirs)
# Out:
# (25, 145)

# %%
class BratsDataset (Dataset):
    def __init__ (self, img_dirs, modality_types, transform = None):
        self.img_dirs = img_dirs
        self.transform = transform

    def __len__ (self):
        return len (self.img_dirs)

    def __getitem__(self, index):
        imgs_path = self.img_dirs[index]
        patient_id = os.path.basename(imgs_path)
        image = self.concat_imgs(imgs_path)

        # Update the mask file name format
        mask = np.array(Image.open(f'{imgs_path}/{patient_id}_seg-slice077.jpg'))
        mask = (mask / 255 * 4).round()
        mask = self.preprocess_mask_labels(mask)

        if self.transform is not None:
            augmented = self.transform(image=image, mask=mask)
            image = augmented['image']
            mask = augmented['mask']

         # Select only the first channel from the mask
        mask = mask[..., 0]
        return image.astype(float), mask.astype(float)


    def concat_imgs(self, path: str):
      patient_id = os.path.basename(path)  # Extracts the patient ID from the full path
      types = []
      for modality_type in modality_types:
          img = np.array(Image.open(f'{path}/{patient_id}_{modality_type}-slice077.jpg'))
          img = self.normalize(img)
          types.append(img)
      #return np.array(types)
      return np.array(types)[..., 0]


    def preprocess_mask_labels(self, mask: np.ndarray):
        mask_WT = np.zeros(mask.shape)
        mask_WT[mask == 2] = 1

        mask_TC = np.zeros(mask.shape)
        mask_TC[mask == 1] = 1

        mask_ET = np.zeros(mask.shape)
        mask_ET[mask == 3] = 1

        mask_BG = np.zeros(mask.shape)
        mask_BG[mask == 0] = 1

        mask = np.stack([mask_WT, mask_TC, mask_ET, mask_BG])
        # mask = np.moveaxis(mask, (0, 1, 2), (0, 2, 1))
        return mask

    def normalize(self, data: np.ndarray):
        data_min = np.min(data)
        if np.max(data) == 0:
            return data
        if (np.max(data) - data_min) == 0:
            return data / data_min

        return (data - data_min) / (np.max(data) - data_min)

    trn_tfms = A.Compose (
[
    A.Resize (height = 240, width = 240),
    #     A.Rotate (limit = 35, p = 1.0),
    #     A.HorizontalFlip (p = 0.5),
    #     A.VerticalFlip (p = 0.1),
        # A.Normalize (mean=0.5, std=0.5, max_pixel_value = 255.0),
            # img = (img - mean * max_pixel_value) / (std * max_pixel_value)
    #     ToTensorV2 ()
            # The numpy HWC image is converted to pytorch CHW tensor. If the image is in HW format (grayscale image), it will be converted to pytorch HW tensor.
])

val_tfms = A.Compose (
[
    A.Resize (height = 240, width = 240),
    #     A.Normalize (0.5, 0.5, max_pixel_value = 255.0),
    #     ToTensorV2 ()
])

modality_types = ['flair', 't1', 't1ce', 't2']

# %%
train_ds = BratsDataset(train_dirs, modality_types)
valid_ds = BratsDataset(valid_dirs, modality_types)
train_dl = DataLoader(train_ds, batch_size = 8, shuffle = False, num_workers = 2, pin_memory = True)
valid_dl = DataLoader(valid_ds, batch_size = 8, shuffle = False, num_workers = 2, pin_memory = True)

# %%
dl_it = iter(train_dl)

# Fetch and display information from the first few batches
for _ in range(4):
    imgs, msks = next(dl_it)
    print(imgs.shape)
    print(msks.shape)

# Shuffle the data
idx = np.random.permutation(imgs.shape[0])
imgs = imgs[idx]
msks = msks[idx]

# Visualize the data
plt.figure(figsize=(15, 10))
for i in range(4):
    for j in range(len(modality_types)):
        plt.subplot(4, 5, 5 * i + j + 1)
        plt.imshow(imgs[i][j], cmap='bone')
        plt.axis('off')
        plt.title(modality_types[j])

    plt.subplot(4, 5, 5 * i + 5)
    plt.imshow(256 - (np.argmax(msks[i], axis=0) * 80), cmap='gray')
    plt.axis('off')
    plt.title('Mask')
# Out:
# torch.Size([8, 4, 240, 240])
# torch.Size([8, 4, 240, 240])
# torch.Size([8, 4, 240, 240])
# torch.Size([8, 4, 240, 240])
# torch.Size([8, 4, 240, 240])
# torch.Size([8, 4, 240, 240])
# torch.Size([8, 4, 240, 240])
# torch.Size([8, 4, 240, 240])

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class DoubleConv(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""

    def __init__(self, in_channels, out_channels, mid_channels=None):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)


class Down(nn.Module):
    """Downscaling with maxpool then double conv"""

    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels, out_channels)
        )

    def forward(self, x):
        return self.maxpool_conv(x)


class Up(nn.Module):
    """Upscaling then double conv"""

    def __init__(self, in_channels, out_channels, bilinear=True):
        super().__init__()

        # if bilinear, use the normal convolutions to reduce the number of channels
        if bilinear:
            self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
            self.conv = DoubleConv(in_channels, out_channels, in_channels // 2)
        else:
            self.up = nn.ConvTranspose2d(in_channels, in_channels // 2, kernel_size=2, stride=2)
            self.conv = DoubleConv(in_channels, out_channels)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        # input is CHW
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        # if you have padding issues, see
        # https://github.com/HaiyongJiang/U-Net-Pytorch-Unstructured-Buggy/commit/0e854509c2cea854e247a9c615f175f76fbb2e3a
        # https://github.com/xiaopeng-liao/Pytorch-UNet/commit/8ebac70e633bac59fc22bb5195e513d5832fb3bd
        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)


class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        # self.activation = nn.Softmax()
    def forward(self, x):
        return self.conv(x)
        # return self.activation(self.conv(x))


class UNet(nn.Module):
    def __init__(self, n_channels, n_classes, bilinear=True):
        super(UNet, self).__init__()
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.bilinear = bilinear

        self.inc = DoubleConv(n_channels, 64)
        self.down1 = Down(64, 128)
        self.down2 = Down(128, 256)
        self.down3 = Down(256, 512)
        factor = 2 if bilinear else 1
        self.down4 = Down(512, 1024 // factor)
        self.up1 = Up(1024, 512 // factor, bilinear)
        self.up2 = Up(512, 256 // factor, bilinear)
        self.up3 = Up(256, 128 // factor, bilinear)
        self.up4 = Up(128, 64, bilinear)
        self.outc = OutConv(64, n_classes)

    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x = self.up1(x5, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        logits = self.outc(x)
        return logits

# %%
def dice_coef_metric(probabilities: torch.Tensor,
                     truth: torch.Tensor,
                     treshold: float = 0.5,
                     eps: float = 1e-9) -> np.ndarray:
    """
    Calculate Dice score for data batch.
    Params:
        probobilities: model outputs after activation function.
        truth: truth values.
        threshold: threshold for probabilities.
        eps: additive to refine the estimate.
        Returns: dice score aka f1.
    """
    scores = []
    num = probabilities.shape[0]
    predictions = (probabilities >= treshold).float()
    assert(predictions.shape == truth.shape)
    for i in range(num):
        prediction = predictions[i]
        truth_ = truth[i]
        intersection = 2.0 * (truth_ * prediction).sum()
        union = truth_.sum() + prediction.sum()
        if truth_.sum() == 0 and prediction.sum() == 0:
            scores.append(1.0)
        else:
            scores.append((intersection + eps) / union)
    return np.mean(scores)


def jaccard_coef_metric(probabilities: torch.Tensor,
               truth: torch.Tensor,
               treshold: float = 0.5,
               eps: float = 1e-9) -> np.ndarray:
    """
    Calculate Jaccard index for data batch.
    Params:
        probobilities: model outputs after activation function.
        truth: truth values.
        threshold: threshold for probabilities.
        eps: additive to refine the estimate.
        Returns: jaccard score aka iou."
    """
    scores = []
    num = probabilities.shape[0]
    predictions = (probabilities >= treshold).float()
    assert(predictions.shape == truth.shape)

    for i in range(num):
        prediction = predictions[i]
        truth_ = truth[i]
        intersection = (prediction * truth_).sum()
        union = (prediction.sum() + truth_.sum()) - intersection + eps
        if truth_.sum() == 0 and prediction.sum() == 0:
            scores.append(1.0)
        else:
            scores.append((intersection + eps) / union)
    return np.mean(scores)


class Meter:
    '''factory for storing and updating iou and dice scores.'''
    def __init__(self, treshold: float = 0.5):
        self.threshold: float = treshold
        self.dice_scores: list = []
        self.iou_scores: list = []

    def update(self, logits: torch.Tensor, targets: torch.Tensor):
        """
        Takes: logits from output model and targets,
        calculates dice and iou scores, and stores them in lists.
        """
        probs = torch.sigmoid(logits)
        dice = dice_coef_metric(probs, targets, self.threshold)
        iou = jaccard_coef_metric(probs, targets, self.threshold)

        self.dice_scores.append(dice)
        self.iou_scores.append(iou)

    def get_metrics(self) -> np.ndarray:
        """
        Returns: the average of the accumulated dice and iou scores.
        """
        dice = np.mean(self.dice_scores)
        iou = np.mean(self.iou_scores)
        return dice, iou


class DiceLoss(nn.Module):
    """Calculate dice loss."""
    def __init__(self, eps: float = 1e-9):
        super(DiceLoss, self).__init__()
        self.eps = eps

    def forward(self,
                logits: torch.Tensor,
                targets: torch.Tensor) -> torch.Tensor:

        num = targets.size(0)
        probability = torch.sigmoid(logits)
        probability = probability.view(num, -1)
        targets = targets.view(num, -1)
        assert(probability.shape == targets.shape)

        intersection = 2.0 * (probability * targets).sum()
        union = probability.sum() + targets.sum()
        dice_score = (intersection + self.eps) / union
        #print("intersection", intersection, union, dice_score)
        return 1.0 - dice_score


class BCEDiceLoss(nn.Module):
    """Compute objective loss: BCE loss + DICE loss."""
    def __init__(self):
        super(BCEDiceLoss, self).__init__()
        self.bce = nn.BCEWithLogitsLoss()
        self.dice = DiceLoss()

    def forward(self,
                logits: torch.Tensor,
                targets: torch.Tensor) -> torch.Tensor:
        assert(logits.shape == targets.shape)
        dice_loss = self.dice(logits, targets)
        bce_loss = self.bce(logits, targets)

        return bce_loss + dice_loss

# helper functions for testing.
def dice_coef_metric_per_classes(probabilities: np.ndarray,
                                    truth: np.ndarray,
                                    treshold: float = 0.5,
                                    eps: float = 1e-9,
                                    classes: list = ['WT', 'TC', 'ET', 'BG']) -> np.ndarray:
    """
    Calculate Dice score for data batch and for each class.
    Params:
        probobilities: model outputs after activation function.
        truth: model targets.
        threshold: threshold for probabilities.
        eps: additive to refine the estimate.
        classes: list with name classes.
        Returns: dict with dice scores for each class.
    """
    scores = {key: list() for key in classes}
    num = probabilities.shape[0]
    num_classes = probabilities.shape[1]
    predictions = (probabilities >= treshold).astype(np.float32)
    assert(predictions.shape == truth.shape)

    for i in range(num):
        for class_ in range(num_classes):
            prediction = predictions[i][class_]
            truth_ = truth[i][class_]
            intersection = 2.0 * (truth_ * prediction).sum()
            union = truth_.sum() + prediction.sum()
            if truth_.sum() == 0 and prediction.sum() == 0:
                 scores[classes[class_]].append(1.0)
            else:
                scores[classes[class_]].append((intersection + eps) / union)

    return scores


def jaccard_coef_metric_per_classes(probabilities: np.ndarray,
               truth: np.ndarray,
               treshold: float = 0.5,
               eps: float = 1e-9,
               classes: list = ['WT', 'TC', 'ET', 'BG']) -> np.ndarray:
    """
    Calculate Jaccard index for data batch and for each class.
    Params:
        probobilities: model outputs after activation function.
        truth: model targets.
        threshold: threshold for probabilities.
        eps: additive to refine the estimate.
        classes: list with name classes.
        Returns: dict with jaccard scores for each class."
    """
    scores = {key: list() for key in classes}
    num = probabilities.shape[0]
    num_classes = probabilities.shape[1]
    predictions = (probabilities >= treshold).astype(np.float32)
    assert(predictions.shape == truth.shape)

    for i in range(num):
        for class_ in range(num_classes):
            prediction = predictions[i][class_]
            truth_ = truth[i][class_]
            intersection = (prediction * truth_).sum()
            union = (prediction.sum() + truth_.sum()) - intersection + eps
            if truth_.sum() == 0 and prediction.sum() == 0:
                 scores[classes[class_]].append(1.0)
            else:
                scores[classes[class_]].append((intersection + eps) / union)

    return scores

# %%
class Trainer:
    """
    Factory for training proccess.
    Args:
        display_plot: if True - plot train history after each epoch.
        net: neural network for mask prediction.
        criterion: factory for calculating objective loss.
        optimizer: optimizer for weights updating.
        phases: list with train and validation phases.
        dataloaders: dict with data loaders for train and val phases.
        path_to_csv: path to csv file.
        meter: factory for storing and updating metrics.
        batch_size: data batch size for one step weights updating.
        num_epochs: num weights updation for all data.
        accumulation_steps: the number of steps after which the optimization step can be taken
                    (https://www.kaggle.com/c/understanding_cloud_organization/discussion/105614).
        lr: learning rate for optimizer.
        scheduler: scheduler for control learning rate.
        losses: dict for storing lists with losses for each phase.
        jaccard_scores: dict for storing lists with jaccard scores for each phase.
        dice_scores: dict for storing lists with dice scores for each phase.
    """
    def __init__(self,
                 net: nn.Module,
                 train_dl: DataLoader,
                 val_dl: DataLoader,
                 criterion: nn.Module,
                 lr: float,
                 accumulation_steps: int,
                 batch_size: int,
                 num_epochs: int,
                 display_plot: bool = True,

                ):

        """Initialization."""
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        print("device:", self.device)
        self.display_plot = display_plot
        self.net = net
        self.net = self.net.to(self.device)
        self.criterion = criterion
        self.optimizer = Adam(self.net.parameters(), lr=lr)
        self.scheduler = ReduceLROnPlateau(self.optimizer, mode="min",
                                           patience=2, verbose=True)
        self.accumulation_steps = accumulation_steps // batch_size
        self.phases = ["train", "val"]
        self.num_epochs = num_epochs
        self.dataloaders = {
            "train": train_dl,
            "val"  : val_dl
        }
        self.best_loss = float("inf")
        self.losses = {phase: [] for phase in self.phases}
        self.dice_scores = {phase: [] for phase in self.phases}
        self.jaccard_scores = {phase: [] for phase in self.phases}

    def _compute_loss_and_outputs(self,
                                  images: torch.Tensor,
                                  targets: torch.Tensor):
        images = images.to(self.device)
        targets = targets.to(self.device)
        logits = self.net(images.float())
        loss = self.criterion(logits, targets)
        return loss, logits

    def _do_epoch(self, epoch: int, phase: str):
        print(f"{phase} epoch: {epoch} | time: {time.strftime('%H:%M:%S')}")

        self.net.train() if phase == "train" else self.net.eval()
        meter = Meter()
        dataloader = self.dataloaders[phase]
        total_batches = len(dataloader)
        running_loss = 0.0
        self.optimizer.zero_grad()
        for itr, (images, targets) in enumerate(dataloader):
#             print(images.shape, targets.shape)
#             images, targets = data_batch['image'], data_batch['mask']
            loss, logits = self._compute_loss_and_outputs(images, targets)
            loss = loss / self.accumulation_steps
            if phase == "train":
                loss.backward()
                if (itr + 1) % self.accumulation_steps == 0:
                    self.optimizer.step()
                    self.optimizer.zero_grad()
            running_loss += loss.item()
            meter.update(logits.detach().cpu(),
                         targets.detach().cpu()
                        )

        epoch_loss = (running_loss * self.accumulation_steps) / total_batches
        epoch_dice, epoch_iou = meter.get_metrics()

        self.losses[phase].append(epoch_loss)
        self.dice_scores[phase].append(epoch_dice)
        self.jaccard_scores[phase].append(epoch_iou)

        return epoch_loss

    def run(self):
        for epoch in range(self.num_epochs):
            self._do_epoch(epoch, "train")
            with torch.no_grad():
                val_loss = self._do_epoch(epoch, "val")
                self.scheduler.step(val_loss)
            if self.display_plot:
                self._plot_train_history()

            if val_loss < self.best_loss:
                print(f"\n{'#'*20}\nSaved new checkpoint\n{'#'*20}\n")
                self.best_loss = val_loss
                torch.save(self.net.state_dict(), "best_model.pth")
            print()
        self._save_train_history()

    def _plot_train_history(self):
        data = [self.losses, self.dice_scores, self.jaccard_scores]
        colors = ['deepskyblue', "crimson"]
        labels = [
            f"""
            train loss {self.losses['train'][-1]}
            val loss {self.losses['val'][-1]}
            """,

            f"""
            train dice score {self.dice_scores['train'][-1]}
            val dice score {self.dice_scores['val'][-1]}
            """,

            f"""
            train jaccard score {self.jaccard_scores['train'][-1]}
            val jaccard score {self.jaccard_scores['val'][-1]}
            """,
        ]

        clear_output(True)
        with plt.style.context("seaborn-dark-palette"):
            fig, axes = plt.subplots(3, 1, figsize=(8, 10))
            for i, ax in enumerate(axes):
                ax.plot(data[i]['val'], c=colors[0], label="val")
                ax.plot(data[i]['train'], c=colors[-1], label="train")
                ax.set_title(labels[i])
                ax.legend(loc="upper right")

            plt.tight_layout()
            plt.show()

    def load_predtrain_model(self,
                             state_path: str):
        self.net.load_state_dict(torch.load(state_path))
        print("Predtrain model loaded")

    def _save_train_history(self):
        """writing model weights and training logs to files."""
        torch.save(self.net.state_dict(),
                   f"last_epoch_model.pth")

        logs_ = [self.losses, self.dice_scores, self.jaccard_scores]
        log_names_ = ["_loss", "_dice", "_jaccard"]
        logs = [logs_[i][key] for i in list(range(len(logs_)))
                         for key in logs_[i]]
        log_names = [key+log_names_[i]
                     for i in list(range(len(logs_)))
                     for key in logs_[i]
                    ]
        pd.DataFrame(
            dict(zip(log_names, logs))
        ).to_csv("train_log.csv", index=False)

# %%
batch_size = 8
# train_dirs=train_dirs[:200]
# valid_dirs=valid_dirs[:200]
train_ds = BratsDataset(train_dirs, modality_types)
valid_ds = BratsDataset(valid_dirs, modality_types)
train_dl = DataLoader(train_ds, batch_size = batch_size, shuffle = False, num_workers = 2, pin_memory = True)
valid_dl = DataLoader(valid_ds, batch_size = batch_size, shuffle = False, num_workers = 2, pin_memory = True)
print(len(valid_dl ), len(train_dl))
device = torch.device ('cuda' if torch.cuda.is_available() else 'cpu')
model = UNet(n_channels=4, n_classes=4, bilinear=True).to(device).float()
# Out:
# 4 19

# %%
from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau
from tqdm import tqdm

trainer = Trainer(net=model,
                  train_dl=train_dl,
                  val_dl=valid_dl,
                  criterion=BCEDiceLoss(),
                  lr=5e-4,
                  accumulation_steps=batch_size,
                  batch_size=batch_size,
                  num_epochs=10,
                 )
# Out:
# device: cuda

# %%
# %%time
trainer.run()
# Out:
# ####################
# Saved new checkpoint
# ####################
#
#
# CPU times: user 1min 15s, sys: 7.58 s, total: 1min 23s
# Wall time: 1min 52s

# %%
def compute_scores_per_classes(model,
                               dataloader,
                               classes):
    """
    Compute Dice and Jaccard coefficients for each class.
    Params:
        model: neural net for make predictions.
        dataloader: dataset object to load data from.
        classes: list with classes.
        Returns: dictionaries with dice and jaccard coefficients for each class for each slice.
    """
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    dice_scores_per_classes = {key: list() for key in classes}
    iou_scores_per_classes = {key: list() for key in classes}

    with torch.no_grad():
        for i, (imgs, targets) in enumerate(dataloader):
#             imgs, targets = data['image'], data['mask']
            imgs, targets = imgs.to(device), targets.to(device)
            logits = model(imgs.float())
            logits = logits.detach().cpu().numpy()
            targets = targets.detach().cpu().numpy()


            dice_scores = dice_coef_metric_per_classes(logits, targets)
            iou_scores = jaccard_coef_metric_per_classes(logits, targets)
            for key in dice_scores.keys():
                dice_scores_per_classes[key].extend(dice_scores[key])

            for key in iou_scores.keys():
                iou_scores_per_classes[key].extend(iou_scores[key])

    return dice_scores_per_classes, iou_scores_per_classes

# %%
valid_ds = BratsDataset(valid_dirs, modality_types)
valid_dl = DataLoader(valid_ds, batch_size = batch_size, shuffle = False, num_workers = 2, pin_memory = True)

# %%
model.eval();

# %%
# %%time
dice_scores_per_classes, iou_scores_per_classes = compute_scores_per_classes(
    model, valid_dl, ['WT', 'TC', 'ET', 'BG']
    )
# Out:
# CPU times: user 349 ms, sys: 134 ms, total: 484 ms
# Wall time: 1.85 s

# %%
dice_df = pd.DataFrame(dice_scores_per_classes)
dice_df.columns = ['WT dice', 'TC dice', 'ET dice', 'BG dice']

iou_df = pd.DataFrame(iou_scores_per_classes)
iou_df.columns = ['WT jaccard', 'TC jaccard', 'ET jaccard', 'BG jaccard']
val_metics_df = pd.concat([dice_df, iou_df], axis=1, sort=True)
val_metics_df = val_metics_df.loc[:, ['WT dice', 'WT jaccard',
                                      'TC dice', 'TC jaccard',
                                      'ET dice', 'ET jaccard',
                                      'BG dice', 'BG jaccard']]
val_metics_df.sample(5)
# Out:
#          WT dice    WT jaccard       TC dice    TC jaccard       ET dice  \
# 22  1.479786e-01  7.990115e-02  9.578544e-13  9.578544e-13  9.009009e-12
# 6   4.405286e-12  4.405286e-12  5.000000e-10  5.000000e-10  1.960784e-11
# 7   4.546584e-01  2.942122e-01  3.215434e-12  3.215434e-12  5.917160e-12
# 9   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 18  2.610966e-12  2.610966e-12  3.030303e-11  3.030303e-11  2.325581e-11
#
#       ET jaccard   BG dice  BG jaccard
# 22  9.009009e-12  0.996714    0.993449
# 6   1.960784e-11  0.996880    0.993780
# 7   5.917160e-12  0.994768    0.989590
# 9   1.000000e+00  1.000000    1.000000
# 18  2.325581e-11  0.992866    0.985833

# %%
colors = ['#35FCFF', '#FF355A', '#96C503', '#C5035B', '#28B463', '#35FFAF']
palette = sns.color_palette(colors, 6)

fig, ax = plt.subplots(figsize=(12, 6));
sns.barplot(x=val_metics_df.mean().index, y=val_metics_df.mean(), palette=palette, ax=ax);
ax.set_xticklabels(val_metics_df.columns, fontsize=14, rotation=15);
ax.set_title("Dice and Jaccard Coefficients from Validation", fontsize=20)

for idx, p in enumerate(ax.patches):
        percentage = '{:.1f}%'.format(100 * val_metics_df.mean().values[idx])
        x = p.get_x() + p.get_width() / 2 - 0.15
        y = p.get_y() + p.get_height()
        ax.annotate(percentage, (x, y), fontsize=15, fontweight="bold")

fig.savefig("result1.png", format="png",  pad_inches=0.2, transparent=False, bbox_inches='tight')
fig.savefig("result1.svg", format="svg",  pad_inches=0.2, transparent=False, bbox_inches='tight')
# Out:
# <ipython-input-27-098ee2373102>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=val_metics_df.mean().index, y=val_metics_df.mean(), palette=palette, ax=ax);
# <ipython-input-27-098ee2373102>:5: UserWarning:
# The palette list has fewer values (6) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=val_metics_df.mean().index, y=val_metics_df.mean(), palette=palette, ax=ax);
# <ipython-input-27-098ee2373102>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(val_metics_df.columns, fontsize=14, rotation=15);

# %%
def show_results(model, test_dl, checkpoint_path=None):
    if checkpoint_path is not None:
        load_checkpoint(torch.load(checkpoint_path), model)

    dl_iter = iter(test_dl)
    images, masks = next(dl_iter)

    for BB in range(4):
        images, masks = next(dl_iter)
        images = images.to(device)
        masks = masks.to(device)

        preds = torch.argmax(model(images.float()), dim=1)
        masks = torch.argmax(masks, dim=1)
        masks = masks * 84
        preds = preds * 84

        mean = 0.5
        std = 0.5
        plt.figure(figsize=(20, 40))

        for i in range(8):
            for j in range(len(modality_types)):
                plt.subplot(16, 6, 6 * i + j + 1)
                plt.axis('off')
                plt.title(modality_types[j])

                if images[i].dim() == 3:
                    plt.imshow(images[i][j].cpu(), cmap='bone')
                elif images[i].dim() == 4:
                    plt.imshow(images[i][0][j].cpu(), cmap='bone')  # Assuming batch_size is 1
                else:
                    raise ValueError("Unexpected dimension in images")

            plt.subplot(16, 6, 6 * i + 5)
            plt.title('True Mask')
            plt.axis('off')
            plt.imshow(255 - masks[i].cpu(), cmap='bone')

            plt.subplot(16, 6, 6 * i + 6)
            plt.title('Predicted Mask')
            plt.axis('off')
            plt.imshow(255 - preds[i].cpu(), cmap='bone')

        plt.show()

    return masks, preds

# Example usage
show_results(model, valid_dl, checkpoint_path=None)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-e4bd0117174f> in <cell line: 50>()
#      48
#      49 # Example usage
# ---> 50 show_results(model, valid_dl, checkpoint_path=None)
#
# <ipython-input-32-e4bd0117174f> in show_results(model, test_dl, checkpoint_path)
#      26                 plt.title(modality_types[j])
#      27
# ---> 28                 if images[i].dim() == 3:
#      29                     plt.imshow(images[i][j].cpu(), cmap='bone')
#      30                 elif images[i].dim() == 4:
#
# IndexError: index 1 is out of bounds for dimension 0 with size 1
